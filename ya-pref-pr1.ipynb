# %% [markdown]
# <div style="border:solid lightblue 2px; padding: 20px">
#
# Привет, Даниил!  Рада, что удалось доработать проект. Обозначения прежние, тольео отмечаю версией 2</div>

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# Привет, Даниил! Меня зовут Татьяна, и я буду проверять твою работу. Предлагаю общаться на «ты» :) Но если это не удобно - дай знать, и мы перейдем на "вы".
#
# Над проектом проделана уже большая работа, но давай сделаем его еще лучше.
# Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Всё это поможет выполнить повторную проверку твоего проекта оперативнее
# Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>❌Так выделены критичные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⚠️ Так выделены небольшие замечания.Такие замечания в проекте допустимы, это пространство для улучшений в будущем.
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>✔️Так я выделяю успешные идеи, даю советы на будущее.</div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комменатри — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>❌Обратила внимание, что номера ячеек в проекте были пронумерованы не с 1. Это бывает, когда проект не перезапущен на платфоме. Из-за этого ты не заметил, что не все разделы проекта выполнены. Это было бы препятствием для проверки, но вижу, что не работает только добоплнительный раздел. Очень здорово, что ты рассмотрел дополнительный вопрос, но пожалуйста, восстанови работоспособность кода в нем и будет отлично. </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера 2:</b>⚠️ Даниил, твой проект был снова не перезагружен. 😳 Здорово, что все работает, но, пожалуйста обращай внимание на этот момент. Однажды он спасет тебя от возврата проекта. Будет обидно, если горит дедлайн, например ))
# </div>

# %% [markdown]
# # Исследование продаж компьютерных игр #

# %% [markdown]
# **Описание проекта**

# %% [markdown]
# Я работаю в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Передо мной поставили задачу по выявлению определяющих успешность игры закономерностей. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании. У меня на руках данные до 2016 года, и мне необходимо спланировать кампанию на 2017-й. Нужно отработать принцип работы с данными.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# __Описание данных__
#
# >`Name` — название игры
# >`Platform` — платформа
# >`Year_of_Release` — год выпуска
# >`Genre` — жанр игры
# >`NA_sales` — продажи в Северной Америке (миллионы проданных копий)
# >`EU_sales` — продажи в Европе (миллионы проданных копий)
# >`JP_sales` — продажи в Японии (миллионы проданных копий)
# >`Other_sales` — продажи в других странах (миллионы проданных копий)
# >`Critic_Score` — оценка критиков (максимум 100)
# >`User_Score` — оценка пользователей (максимум 10)
# >`Rating` — рейтинг от организации ESRB (англ. Entertainment Software Rating Board)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>✔️ Отлично, что делаешь вступление к проекту, постановку целей и даешь описание данных.  Каждый сможет разобраться с тем, что мы исследуем и сами не забудем, какие выводы от нас ждут.</div>

# %% [markdown]
# ## Изучение данных ##

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats as st

# %%
df = pd.read_csv("/datasets/games.csv")

# %%
df.head(20)
# Out:
#                                             Name Platform  Year_of_Release  \
# 0                                     Wii Sports      Wii           2006.0
# 1                              Super Mario Bros.      NES           1985.0
# 2                                 Mario Kart Wii      Wii           2008.0
# 3                              Wii Sports Resort      Wii           2009.0
# 4                       Pokemon Red/Pokemon Blue       GB           1996.0
# 5                                         Tetris       GB           1989.0
# 6                          New Super Mario Bros.       DS           2006.0
# 7                                       Wii Play      Wii           2006.0
# 8                      New Super Mario Bros. Wii      Wii           2009.0
# 9                                      Duck Hunt      NES           1984.0
# 10                                    Nintendogs       DS           2005.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# **Выводы по разделу**

# %% [markdown]
# Полученные данные необходимо обработать, т.к. присутствуют неправильные типы данных и пропуски.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>✔️Молодец! Все библиотеки загружены в одном месте, есть первый взгляд на данные, первые проблемы озвучены, есть над чем подумать и исправить на этапе предобработки.
# </div>

# %% [markdown]
# ## Подготовка данных ##

# %% [markdown]
# ### Замена названия столбцов ###

# %% [markdown]
# Для удобства работы со столбцами привел их наименования к нижнему регистру.

# %%
df.columns = df.columns.str.lower()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>✔️Молодец. Этот метод помогает избежать ошибок при обращении к столбцам. </div>

# %% [markdown]
# ### Обработка пропусков и преобразование данных в нужные типы ###

# %% [markdown]
# Пропуски присутствуют в столбцах `name` , `year_of_release` , `genre`, `critic_score`, `user_score` и `rating`. Обработать первые 3, скорее всего, не составит труда, с оставшимися тремя, вероятно, ничего сделать не получится.

# %%
df.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# Процентнтное соотношение имеющихся пропусков

# %%
round((df.isna().sum() / len(df) * 100), 2)
# Out:
# name                0.01
# platform            0.00
# year_of_release     1.61
# genre               0.01
# na_sales            0.00
# eu_sales            0.00
# jp_sales            0.00
# other_sales         0.00
# critic_score       51.32
# user_score         40.09
# rating             40.48
# dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⚠️ Имеет смысл сразу оценивать пропуски в данных не только количственно, но и в процентах от имеющихся данных. Так мы сможем принимать обоснованные решения по удалению/не удалению, заполнению/не заполнению, оценивая влияние на дальнейшее исследование.
# </div>

# %% [markdown]
# <div class="alert alert-info"></div>
#
# Пропуски в столбцах `critic_score`, `user_score` и `rating` составляют более 40% от общего объема датасета. Удаление строк с пропусками из данных столбцов может привести к серьезной потере данных. Поэтому строки с пропусками в этих столбцах оставляем на месте.
#
# <div class="alert alert-info"></div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера 2:</b>✔️ Молодец.  сразу виден весь масштаб катастрофы, что мы можем себе позволить в  предобработке, а что ни в коем случае.</div>

# %% [markdown]
# Неправильные типы данных в следующих столбцах:
#
# >`year_of_release` (float -> int)
# >`user_score` (object -> float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# #### Столбец `year_of_release`

# %% [markdown]
# Так как количество пропусков в данном столбце значительно меньше по сравнению с общим количеством строк, можно удалить данные из датафрейма. Дополнительно исправил тип данных на целочисленный, так как в данном столбце указаны года выпуска игр.

# %%
df = df.dropna(subset=['year_of_release']).reset_index(drop=True)
df['year_of_release'] = df['year_of_release'].astype('int')

# %%
print('Количество пропусков в столбце "year_of_release":', df['year_of_release'].isna().sum())
# Out:
# Количество пропусков в столбце "year_of_release": 0

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>✔️Согласна с удалением и заменой типа данных. </div>

# %% [markdown]
# #### Столбец `user_score`

# %% [markdown]
# В столбце `user_score` присутствует аббревиатура `tbd`, расшифровывающееся, как `To Be Determined` или `Будет определено`. Так как конкретных значений оно не определяет, заменил ее на стандартный `NaN`. Дополнительно исправил тип данных на число с плавающей запятой, так как в данном столбце указана средняя оценка пользователей, которая может представлять десятичную дробь и не может превышать 10 баллов.

# %%
df['user_score'] = df['user_score'].replace('tbd', np.NaN)
df['user_score'] = df['user_score'].astype('float')

# %% [markdown]
# Проверка правильности обработки данных в столбце.

# %%
df[(df['user_score'] == 'tbd') | (df['user_score'] >= 10)]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>✔️Согласна. tbd это и есть по сути Nan. Такой заменой, мы сохраним однородность данных</div>

# %% [markdown]
# #### Столбец `rating`

# %% [markdown]
# Для удобства восприятия переименую столбец, так как данные в нем связаны конкретно с **возрастным** рейтингом.

# %%
df = df.rename(columns={"rating": "age_rating"})
df['age_rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# Для полного понимания информации из данного столбца была изучена информация из Википедии: https://ru.wikipedia.org/wiki/Entertainment_Software_Rating_Board
#
# 1. `«EC» («Early childhood»)` — «Для детей младшего возраста»
# 2. `«E» («Everyone»)` — «Для всех»
# 3. `«E10+» («Everyone 10 and older»)` — «Для всех от 10 лет и старше»
# 4. `«T» («Teen»)` — «Подросткам»
# 5. `«M» («Mature»)` — «Для взрослых»
# 6. `«AO» («Adults Only 18+»)` — «Только для взрослых»
# 7. `«RP» («Rating Pending»)` — «Рейтинг ожидается»
# 8. `«RP 17+» («Rating Pending»)` — «Рейтинг ожидается - примерно 17+»`
#
# Как можно заметить, упоминания рейтиннга `K-A` в современных материалах нет. Это связано с тем, что данный тип рейтинга `K-A (Kids to Adults)` в 1998 году был переименован в Е – для всех возрастов, а чуть позже был добавлен рейтинг Е10+, который стал соответствовать данному типу рейтинга.

# %%
df['age_rating'].value_counts()
# Out:
# E       3921
# T       2905
# M       1536
# E10+    1393
# EC         8
# K-A        3
# RP         1
# AO         1
# Name: age_rating, dtype: int64

# %%
df['age_rating']  = df['age_rating'].replace('K-A', 'E10+')

# %% [markdown]
# Проверка правильности обработки данных в столбце.

# %%
df['age_rating'].value_counts()
# Out:
# E       3921
# T       2905
# M       1536
# E10+    1396
# EC         8
# RP         1
# AO         1
# Name: age_rating, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>✔️Очень здорово было видеть переименование в возрастной рейтинг. Смысл данных здесь действительно стоило подчеркнуть - молодец!
# Очень подробно рассмотрел значения - отлично. </div>

# %% [markdown]
# #### Столбец `name`

# %% [markdown]
# В данном столбце присутствуют 2 пропуска, от которых лучше избавиться, так как определить конкретное название не составляет возможности. В 1993 году выходило достаточно большое количество игр.

# %%
df[df['year_of_release'] == 1993]
# Out:
#                           name platform  year_of_release         genre  \
# 56       Super Mario All-Stars     SNES             1993      Platform
# 472                   Star Fox     SNES             1993       Shooter
# 652                        NaN      GEN             1993           NaN
# 842    Super Street Fighter II     SNES             1993      Fighting
# 882           Mortal Kombat II     SNES             1993      Fighting
# ...                        ...      ...              ...           ...
# 12793         Pachinko Wars II     SNES             1993          Misc
# 12983      Keiba Eight Special     SNES             1993        Sports
# 13134             Beyond Oasis      GEN             1993  Role-Playing
# 14022                      NaN      GEN             1993           NaN
# 15948      Rock N' Roll Racing     SNES             1993        Racing
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# ...

# %% [markdown]
# Можно заметить, что два пропуска для столбца `genre` также попали в срез данных, поэтому со спокойной дущой избавляемся от этих строк.

# %%
df[df['name'].isnull()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 652    NaN      GEN             1993   NaN      1.78      0.53      0.00
# 14022  NaN      GEN             1993   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score age_rating
# 652           0.08           NaN         NaN        NaN
# 14022         0.00           NaN         NaN        NaN

# %%
df = df.dropna(subset=['name']).reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>✔️Согласна с тобой
# </div>

# %% [markdown]
# Проверка правильности обработки данных в столбцах.

# %%
df.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         8981
# age_rating         6676
# dtype: int64

# %% [markdown]
# Большое количество пропусков в столбцах с оценками критиков и пользователей может быть связано с отсутсвием распространенной практики оценивать игры. Более того, отсутствие значения в одном столбце часто сопутствуется отсутствием в остальных двух.
#
# Также стоит учесть информацию о том, что ESRB была основана в 1994 году ассоциацией Interactive Digital Software Association. Таким образом, большая часть выпускаемых игр до 1994 года могла позднее не оцениваться данной компанией.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⚠️ По пропускам в оценках критиков и пользователей - принято.
#
# Вопрос по обработке пропуска в рейтинге остается открытым. Далее ты пишешь о возможных причинах пропуска в связи с годом создания организации, присваивающей рейтинг. Но я рекомендую посмотреть и на страну ее выпускающую. Действительно ли для всех этот рейтинг может быть важен и использоваться.
#
# Очень уместно было бы указать почему не можем удалить такое количество (оцененное в процентах) данных.
# </div>

# %% [markdown]
# <div class="alert alert-info"></div>
#
# Изучив дополнительный материал, выяснил, что в США, Канаде и Мексике используется система ESRB, а, например, в Великобритании и большинстве европейских стран - система PEGI. В Японии же за это отвечает CERO.
#
# Таким образом можно сделать вывод, что пропуски связаны не только с годом основания **американской** компании ESRB, но и с тем фактом, что она не была ответственна за выставление рейтинга для игр других регионов.
#
# <div class="alert alert-info"></div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера 2:</b>✔️ Верное замечание. Далее важно воспользоваться этой информацией при оценке влияния рейтинга на продажи в исследовательнской части проекта.</div>

# %%
df[(df['critic_score'].isnull()) | (df['user_score'].isnull()) | (df['age_rating'].isnull())].head(20)
# Out:
#                                          name platform  year_of_release  \
# 1                           Super Mario Bros.      NES             1985
# 4                    Pokemon Red/Pokemon Blue       GB             1996
# 5                                      Tetris       GB             1989
# 9                                   Duck Hunt      NES             1984
# 10                                 Nintendogs       DS             2005
# 12                Pokemon Gold/Pokemon Silver       GB             1999
# 18                          Super Mario World     SNES             1990
# 20              Pokemon Diamond/Pokemon Pearl       DS             2006
# 21                           Super Mario Land       GB             1989
# 22                        Super Mario Bros. 3      NES             1988
# 25              Pokemon Ruby/Pokemon Sapphire      GBA             2002
# 27                Pokemon Black/Pokemon White       DS             2010
# ...

# %% [markdown]
# #### Проверка данных на наличие дубликатов

# %% [markdown]
# В столбце `genre` дубликаты не обнаружены. Из данных открыл для себя новое: сокращение `misc` подразумевает под собой `miscellaneous`, что в переводе означает `разное`.

# %%
df['genre'].value_counts()
# Out:
# Action          3307
# Sports          2306
# Misc            1721
# Role-Playing    1481
# Shooter         1296
# Adventure       1293
# Racing          1226
# Platform         878
# Simulation       857
# Fighting         837
# Strategy         673
# Puzzle           569
# Name: genre, dtype: int64

# %% [markdown]
# В столбце `platform` дубликаты не обнаружены.

# %%
df['platform'].value_counts()
# Out:
# PS2     2127
# DS      2121
# PS3     1306
# Wii     1286
# X360    1232
# PSP     1193
# PS      1190
# PC       957
# GBA      811
# XB       803
# GC       542
# 3DS      512
# PSV      429
# PS4      392
# N64      316
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     116
# NES       98
# GB        97
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# Name: platform, dtype: int64

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>❌ По поиску дубликатов, давай посмотрим подробнее. Мы избавляемся от дублирующих строк. Это явное искажение результатов исследования. Также могут присутствовать и неявные дубликаты (например можем искать в связке нескольких параметров имя-консоль-год)
# Не вижу у тебя в коде проверки датасета на явные дубликаты. Это обязательно нужно добавить.
#
# Если мы говорим далее по поиску неявных дубликатов, то , пожалуйста, объясни свой метод поиска по столбцам.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">.</div>
#
# Действительно, способ странный, когда оформлял - сам был не уверен, что пройдет. Я проверил количество значений по столбцам, одновременно изучив все жанры и консоли, на возможные ошибки в столбцах.
#
# <div class="alert alert-info">.</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера 2:</b>⚠️ Вот иногда и не стоит изобретать велосипед. в pandas есть прекрасный простой способ для определения явных дубликатов https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html
#
#
# Относительно твоего способа, очень не явный на самом деле...
#
# Будет время, посмотри неявные дубликаты как писала в предыдущем комментарии.
# </div>

# %% [markdown]
# #### Cуммарные продажи во всех регионах ###

# %% [markdown]
# Для удобства изучения данных по таблице воспользовался методом `insert` для того, чтобы добавить новыt столбцы на определенную позицию. Синтаксис был изучен здесь: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.insert.html.

# %% [markdown]
# Для расчета суммарных продаж понадобится срез данных о продажах во всех имеющихся регионах, а также продаж, не входящих в статистику этих регионов.

# %%
df.insert(8, 'general_sales', df.loc[:, 'na_sales':'other_sales'].sum(axis=1))

# %%
df.head(10)
# Out:
#                         name platform  year_of_release         genre  \
# 0                 Wii Sports      Wii             2006        Sports
# 1          Super Mario Bros.      NES             1985      Platform
# 2             Mario Kart Wii      Wii             2008        Racing
# 3          Wii Sports Resort      Wii             2009        Sports
# 4   Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                     Tetris       GB             1989        Puzzle
# 6      New Super Mario Bros.       DS             2006      Platform
# 7                   Wii Play      Wii             2006          Misc
# 8  New Super Mario Bros. Wii      Wii             2009      Platform
# 9                  Duck Hunt      NES             1984       Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  general_sales  critic_score  \
# 0     41.36     28.96      3.77         8.45          82.54          76.0
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>✔️Супер!</div>

# %% [markdown]
# ### Выводы по разделу

# %% [markdown]
# Удаление строк с пропусками в таких столбцах, как `name`, `genre` и `year_of_release` не должно повлиять на дальнейший исследовательский анализ, что нельзя сказать про столбцы `critic_score`, `user_score` и `age_rating`. Избавить от большого количества пропусков мы не можем, поэтому оставлем их в датасете.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# #### Сколько игр выпускалось в разные годы?

# %%
df['year_of_release'].hist(figsize=(20, 10), bins=150)
plt.title('Объем выпускаемых игр за разные годы', fontdict = {'fontsize' : 25})
plt.xlabel('Игровые платформы', fontdict = {'fontsize' : 15})
plt.ylabel('Общие продажи', fontdict = {'fontsize' : 15})
plt.show()

# %% [markdown]
# Из гистограммы можно сделать вывод о том, что пик выпуска игр пришелся на период с 2007 по 2010 годы. Всплеском можно назвать 2002 год, так как в период с 1990 года по 2009 год объем выпускаемых игр постепенно увеличивался
#
# Могу предположить, что данные за 2016 год пока не полные, поэтому количество выпущенных игр уменьшилось по сравнению с 2015 годом.
#
# В данном случае можно с уверенностью отбросить данные за период с 1980 по 2000 годы, так как количество выпускаемых игр не столь высоко, по сравнению с другими годами

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⚠️ У тебя замечательный график. Заголовок, подписаны оси на языке проекта - это очень здорово.
#
# Хочу обратить твое внимание на важность выбора количества корзин при построении гистограммы. Здесь выбрав слишком маленькое (как в твоем случае) мы получаем сильное искажение - например выброс 2011 года, всплеск 2016) . Количество корзин меньше чем количество рассматриваемых лет в нашем случае будет давать искажение.
#
#
# Поэтому, пожалуйста, поэкспериментируй с количеством корзин и скорректируй вывод, если потребуется.
# </div>

# %% [markdown]
# <div class="alert alert-info"></div>
#
# Действительно, серьезная ошибка по моей невнимательности! Выводы по гистограмме исправил выше.
#
# <div class="alert alert-info"></div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера 2:</b>✔️ Молодец, что исправил. И даже иногда полезно ошибиться, чтобы понять насколько меняется картина. </div>

# %% [markdown]
# #### Изменения продаж по платформам

# %% [markdown]
# Изучил общее количество выпущенных игр на разные платформы.

# %%
df['platform'].sort_values().hist(figsize=(20, 10), bins=100)
plt.title('Общее количество выпущенных игр на разные платформы', fontdict = {'fontsize' : 25})
plt.xlabel('Игровые платформы', fontdict = {'fontsize' : 15})
plt.ylabel('Количество игр', fontdict = {'fontsize' : 15})
plt.show()

# %% [markdown]
# Из данной гистограммы видно, что наибольшее количество игр (более 2100) был выпущено на игровых платформах японских `Nintendo` и `Sony`, а именно `Nintendo DS` и `Playstation 2`. Далее идут такие платформы, как `Playstation 3`, `Wii` и `Xbox 360`, на которые было выпущено более 1200 игр.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>❌ Аналогично - картина с меньшим количеством корзин искажает выводы. Пожалуйста, поправь.
# (Вот судя по графику максимум у нас у PS2 или PS3? наверное смотрим правую часть столбца. тогда XOne сколько? Это к вопросу искажений на графике)
#
# Вопрос стал красным потому что мы хотим увидеть Общие продажи, тогда должен быть показатель суммарных продаж, но используем просто количество выпущенных игр по платформам. Тогда меняем либо заголовок, либо метод
# </div>

# %% [markdown]
# <div class="alert alert-info"></div>
#
# Исправил гистограмму и описание выше.
#
# <div class="alert alert-info"></div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера 2:</b>✔️ Хорошо</div>

# %% [markdown]
# Для изучения изменений в продажах игр по платформам был выбран самый "свежий" период за 2015 - 2016 годы, из которого можно сделать выводы о том, какие платформы совсем вышли из пользования большей части геймеров, а какие пользуются наибольшим спросом.

# %%
sales_changes = df[df['year_of_release']>=2015].pivot_table(index = ['year_of_release', 'platform'], values = 'general_sales', aggfunc=sum)
sales_changes_sorted = sales_changes.sort_values(by='platform', ascending=False)
sales_changes_sorted.plot(kind = 'bar', figsize=(20,5))
plt.title('Изменения продаж по платформам за период 2015 - 2016 годы', fontdict = {'fontsize' : 25})
plt.xlabel('Год, платформа', fontdict = {'fontsize' : 15})
plt.ylabel('Общие продажи', fontdict = {'fontsize' : 15})
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⚠️ И какие платформы в итоге совсем не попали в 2015-2016? Здесь было бы здорово сделать вывод.
# </div>

# %%
df['platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %% [markdown]
# <div class="alert alert-info"></div>
#
# По гистограмме за 2015-2016 годы можно сделать вывод, что из 31 одной игровой платформы на данный период пользовались спросом только 10 платформ, а это менее, чем 33%. Неоспоримыми лидерами являются `Playstation 4`, `Xbox One` (обе консоли выпущены в 2013 году) и `Nintendo 3DS` (выпущена в 2011 году).
#
# Остальные игровые платформы были выпущены в период с 2004 по 2007 годы, за исключением `WiiU` и `Playstation Vita`, которые были выпущены в 2011 и 2012 годах соответственно.Можно сделать предположение, что данные 2 консоли потеряли пользовательский интерес менее, чем за характерный период существования игровыз платформ на рынке (далее этот вопрос будет рассмотрен детальнее).
#
# <div class="alert alert-info"></div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера 2:</b>✔️ Исправлено.</div>

# %% [markdown]
# #### Лидеры по продажам: растут или падают?

# %% [markdown]
# Лидеры по продажам изучались за весь период представленный в датасете. Рассмотрел топ-5 игровых платформ по количеству проданных игр по всему миру.

# %%
stats_sales = df.pivot_table(index = 'platform', values = 'general_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='general_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#   platform  general_sales
# 0      PS2        1233.56
# 1     X360         961.24
# 2      PS3         931.34
# 3      Wii         891.18
# 4       DS         802.78

# %%
def plot_decor():
    plt.title(i, fontdict = {'fontsize' : 25})
    plt.xlabel('Год', fontdict = {'fontsize' : 15})
    plt.ylabel('Общие продажи', fontdict = {'fontsize' : 15})

# %%
for i in top_sales['platform']:
    df[df['platform'] == i].pivot_table(index = 'year_of_release', values = 'general_sales', aggfunc = 'sum').plot(kind = 'bar', figsize=(20,5))
    plot_decor()

# %% [markdown]
# Изучив гистограммы, можно с уверенностью сказать, что для конкретной компании, например Sony или Microsoft свойственна ситуация, когда новое поколение постепенно полностью замещает старое. Средний "срок жизни" игровой платформы на игровом рынке варьируется от 8 до 10 лет, что в том числе связано с популярностью платформы и скорости выпуска следующего поколения.

# %% [markdown]
# За начало актуального периода было принято взять старт продаж восьмого поколения консолей, к которым относятся такие платформы, как `Wii U` (2012 г.), `Xbox One' и 'PLaystation 4` (2013 г.). Также к консолям 8 поколения относится `Nintendo Switch`, но выпущена она будет только в 2017 году.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>✔️Отлично. Рассмотрел и жизненные циклы платформ, верно определил актуальный период.
# Теперь важно нигде далее не использовать данные ранее выбранного года.</div>

# %%
current_period = df[df['year_of_release']>=2013].reset_index(drop=True)
current_period.head(10)
# Out:
#                                         name platform  year_of_release  \
# 0                         Grand Theft Auto V      PS3             2013
# 1                         Grand Theft Auto V     X360             2013
# 2                  Call of Duty: Black Ops 3      PS4             2015
# 3                        Pokemon X/Pokemon Y      3DS             2013
# 4                         Grand Theft Auto V      PS4             2014
# 5  Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS             2014
# 6                       Call of Duty: Ghosts     X360             2013
# 7                       Call of Duty: Ghosts      PS3             2013
# 8                                  Minecraft     X360             2013
# 9                                    FIFA 16      PS4             2015
#
#           genre  na_sales  eu_sales  jp_sales  other_sales  general_sales  \
# 0        Action      7.02      9.09      0.98         3.96          21.05
# ...

# %% [markdown]
# Из выбранного периода были отобрано 5 наиболее прибыльных игровых платформ.

# %%
stats_sales = current_period.pivot_table(index = 'platform', values = 'general_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='general_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#   platform  general_sales
# 0      PS4         314.14
# 1      PS3         181.43
# 2     XOne         159.32
# 3      3DS         143.25
# 4     X360         136.80

# %%
for i in top_sales['platform']:
    df[df['platform'] == i].pivot_table(index = 'year_of_release', values = 'general_sales', aggfunc = 'sum').plot(kind = 'bar', figsize=(20,5))
    plot_decor()

# %% [markdown]
# Для седьмого поколения консолей свойственна потеря доли покупаемых игр, что связано с выходом восьмого поколения в 2012-2013 годах. Это наиболее заметно по гистограммам для `PS3` и `Xbox 360`.
#
# `PS4` и `Xbox One` стабильно растут начиная с даты их выпуска. Очевидно, что ситуация у `PS4` лучше, что связанно с большим количеством факторов, одним из которых является отсутствие наиболее привлекающих геймеров консольных эксклюзивов. Также видно, что данные за 2016 год не в полном объеме, поэтому кажется, что продажи сильно просели, но в действительности это не так.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⚠️ Задание звучит так:
#
# - Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
#
# Мы начали сразу с определения топ5. Логично было бы посмотреть кто вообще попал в акутальный период, можно даже откровенно отмирающих и исключить ( ты ведь смотрел ранее каких платформ не присутствует в 2015-2016 годах )
#
# По динамике наиболее прибыльных платформ все верно замечаешь. Здорово, что здесь отмечаешь преемственность платформ у компаний.
# </div>

# %% [markdown]
# <div class="alert alert-info"></div>
#
# Лидерами по продажам за период с 2015-2016 голды являются `Playstation 4`, `Xbox One` (обе консоли выпущены в 2013 году) и `Nintendo 3DS` (выпущена в 2011 году).
#
# `Playstation 4` и `Xbox One` начиная с года выпуска стабильно растут по продажам игр. По 2016 году нельзя дать точную оценку, так как, скорее всего, у нас нет полных данных за данный отчетный период.
#
# В свою очередь портативная `Nintendo 3DS` на 2016 год постепенно теряет свои позиции на рынке игр, так изменение объема продаж в 2015 году по сравнению с 2011 годом составило примерно 45%.
#
# <div class="alert alert-info"></div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера 2:</b>✔️ Хорошо </div>

# %% [markdown]
# #### Глобальные продажи игр в разбивке по платформам

# %%
current_period.boxplot(by='platform', column='general_sales', figsize=(10, 30))
plt.title('«Ящик с усами» по глобальным продажам игр в разбивке по платформам', fontdict = {'fontsize' : 15})
plt.xlabel('Платформа', fontdict = {'fontsize' : 15})
plt.ylabel('Общие продажи', fontdict = {'fontsize' : 15})
plt.show()

# %%
current_period.boxplot(by='platform', column='general_sales',showfliers=False, figsize=(20, 10))
plt.title('«Ящик с усами» по глобальным продажам игр в разбивке по платформам (без выбросов)', fontdict = {'fontsize' : 15})
plt.xlabel('Платформа', fontdict = {'fontsize' : 15})
plt.ylabel('Общие продажи', fontdict = {'fontsize' : 15})
plt.show()

# %%
current_period.groupby('platform')['general_sales'].describe()
# Out:
#           count      mean       std   min     25%    50%     75%    max
# platform
# 3DS       303.0  0.472772  1.381347  0.01  0.0400  0.090  0.2800  14.60
# DS          8.0  0.192500  0.172026  0.03  0.0675  0.150  0.2525   0.51
# PC        189.0  0.208624  0.352304  0.01  0.0300  0.080  0.2300   3.05
# PS3       345.0  0.525884  1.451939  0.01  0.0400  0.150  0.5100  21.05
# PS4       392.0  0.801378  1.609456  0.01  0.0600  0.200  0.7300  14.63
# PSP        67.0  0.052239  0.059768  0.01  0.0150  0.020  0.0700   0.24
# PSV       358.0  0.092151  0.153816  0.01  0.0200  0.040  0.1100   1.96
# Wii        23.0  0.593913  0.915432  0.01  0.0450  0.180  0.7550   3.58
# WiiU      115.0  0.562000  1.038778  0.01  0.0600  0.200  0.5950   7.09
# X360      186.0  0.735484  1.663275  0.01  0.0800  0.265  0.7950  16.27
# XOne      247.0  0.645020  1.036139  0.01  0.0600  0.220  0.6850   7.39

# %% [markdown]
# Из полученных данных можно сделать выводы, что наибольшие медианные продажи у `PS4`, `WiiU`, `Xbox 360` и `Xbox One`. С чем может быть связана такая популярность игр для `Xbox 360`? Все просто - функция обратной совместимости с `Xbox One`, которая позволять запускать игры со старой консоли на новом поколении.
#
# У всех игровых платформ присутствуют выбросы, что может быт связано с достаточно большим рассматриваемым периодом, так как ранее были популярны одни, а сейчас - другие.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⚠️ Молодец, что показываешь общую картину со всеми выбросами. Кстати, что здесь скрывается за выбросами ? Как ты их понимаешь?
#
# Стараешься объяснить и популярность той же x360/ здесь ответ скорее в том, что Х360 как раз доживает свой век и в актуальном периоде представлена суммарно всем своим циклом. тот же XBox только набирает обороты.
#
# Пожалуйста, добавь еще такой же график ящик с усами с укрупнением до размаха ящиков. Чтобы можно было и по шкале оценивать количественно. Также обрати внимание на сдвиг медиан к нижнему квартилю - как ты это объяснишь?
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"></div>
#
# На выбранный актуальный период с 2013 по 2016 годы наибольшее количество выбросов у `Nintendo 3DS`, `PS3`, `PS4`, `Xbox 360`, `Xbox One`. Выбросы говорят о наличии высоких продаж. Большие межквартильные размахи можно объяснить тем, что продажи сильно различаются между собой, например, есть большие хиты AAA-проекты) и есть гораздо более скромные игры на любителя (инди-игры).
#
# Сдвиг медиан к нижнему квартилю у некоторых платформ говорит о том, что большая часть данных имеет низкое значение. В нашем случае - малые продажи.
#
# <div class="alert alert-info"></div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера 2:</b>✔️ Да, все верно. Теперь есть и общая картина с хитами продаж и можно детально сравнивать платформы между собой.  Я очень люблю этот тип графика. Очень информативный и рада, что ты с ним разобрался.</div>

# %% [markdown]
# #### Влияние отзывов пользователей и критиков

# %% [markdown]
# Избавлюсь от строк с пропусками в столбцах с оценками критиков и пользователей для более точной оценки их влияния на продажи.

# %%
honest_score = current_period[(~current_period['critic_score'].isnull()) & (~current_period['user_score'].isnull())].reset_index(drop=True)
honest_score
# Out:
#                                   name platform  year_of_release    genre  \
# 0                   Grand Theft Auto V      PS3             2013   Action
# 1                   Grand Theft Auto V     X360             2013   Action
# 2                   Grand Theft Auto V      PS4             2014   Action
# 3                 Call of Duty: Ghosts     X360             2013  Shooter
# 4                 Call of Duty: Ghosts      PS3             2013  Shooter
# ..                                 ...      ...              ...      ...
# 971        Saints Row: Gat out of Hell     XOne             2015   Action
# 972           Sébastien Loeb Rally Evo     XOne             2016   Racing
# 973                   Fast Racing Neo      WiiU             2016   Action
# 974                   Prison Architect     XOne             2016   Action
# 975  Metal Gear Solid V: Ground Zeroes       PC             2014   Action
#
#      na_sales  eu_sales  jp_sales  other_sales  general_sales  critic_score  \
# ...

# %%
for i in honest_score['platform'].unique():
    plat_cor = honest_score.loc[:, 'general_sales' : 'user_score'].corr()
    print('Матрица корреляции для {plat}:\n {mat_cor}\n'.format(plat=i, mat_cor=plat_cor))
    count = 0
    for j in plat_cor['general_sales'].unique():
        if j != 1:          
            if j >= 0.5:
                if count == 0:
                    print('Корреляция по оценкам критиков - заметная')
                elif count == 1:
                    print('Корреляция по оценкам зрителей - заметная')
            elif j >= 0.7:
                if count == 0:
                    print('Корреляция по оценкам критиков - высокая')
                elif count == 1:
                    print('Корреляция по оценкам зрителей - высокая')
            else:
                if count == 0:
                    print('Корреляция по оценкам критиков - низкая')
                elif count == 1:
                    print('Корреляция по оценкам зрителей - низкая')
            count += 1 
      
    plat_stat = honest_score[honest_score['platform'] == i]
    
    plat_stat.plot(x='critic_score', y='general_sales', kind='scatter')
    plt.title('Влияние отзывов критиков на продажи {plat}'.format(plat=i))
    plt.xlabel('Оценки критиков')
    plt.ylabel('Общие продажи')
    plt.show()
    
    plat_stat.plot(x='user_score', y='general_sales', kind='scatter')
    plt.title('Влияние отзывов пользователей на продажи {plat}'.format(plat=i))
    plt.xlabel('Оценки пользователей')
    plt.ylabel('Общие продажи')
    plt.show()
# Out:
# Матрица корреляции для PS3:
#                 general_sales  critic_score  user_score
# general_sales       1.000000      0.311692   -0.004064
# critic_score        0.311692      1.000000    0.502221
# user_score         -0.004064      0.502221    1.000000
#
# Корреляция по оценкам критиков - низкая
# Корреляция по оценкам зрителей - низкая
# Матрица корреляции для X360:
#                 general_sales  critic_score  user_score
# general_sales       1.000000      0.311692   -0.004064
# critic_score        0.311692      1.000000    0.502221
# user_score         -0.004064      0.502221    1.000000
#
# Корреляция по оценкам критиков - низкая
# Корреляция по оценкам зрителей - низкая
# Матрица корреляции для PS4:
#                 general_sales  critic_score  user_score
# general_sales       1.000000      0.311692   -0.004064
# critic_score        0.311692      1.000000    0.502221
# user_score         -0.004064      0.502221    1.000000
#
# Корреляция по оценкам критиков - низкая
# ...

# %% [markdown]
# **Выводы**
#
# Из полученных данных, можно сделать вывод, что оценки простых пользователей и критиков не имеют серьезного влияния на продажи в игровой индустрии.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⚠️ Хорошо. Здесь ты рассчитал коэффициент корреляции, строишь графики и они подписаны (только здесь лучше подписать конкретной платформой).
#
# Делая вывод о силе на основании значения коэффициента, еще важно оценивать силу влияния, используя общепринятую шкалу. Например, шкала Чеддока https://ekonometrik.ru/шкала-чеддока/
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⚠️ Выводы справедливые. В заголовке стоит подписывать конкретной платформой. Было бы более убедительно рассмотреть не только сравнение с 2-3 платформами, а можно автоматизировав этот по сути однообразный процесс рассмотреть прямо по списку. Можно сразу и оценку 'сильно/слабо/нет влияния' также внести как шкалу и автоматически получить вывод.
#
#
# Также важно смотреть зависимости на данных без пропусков.
#
# Пожалуйста, доработай с учетом замечаний этот шаг.
# </div>

# %% [markdown]
# <div class="alert alert-info"></div>
#
# Полностью поправил подраздел, основываясь на Ваших предложениях.
#
# <div class="alert alert-info"></div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера 2:</b>✔️ Отлично доработан шаг. И построения и выводы автоматизированы. Графики все подписаны - молодец!</div>

# %% [markdown]
# #### Общее распределение игр по жанрам

# %% [markdown]
# Наиболее популярными жнарами в игровой индустри оказались `Action`, `Shooters` и `Sports`, что в принципе похоже на правду. Тем не менее, победа экшн-игр тесно связана с объемом игр выпускаемых в данном жанре. Шутеров выпускается менее, чем в 4.1 раз, но общая выручка менее только в 1.4 раза, что показательный параметр.

# %%
genre_games = current_period.pivot_table(index = 'genre', values = 'general_sales', aggfunc = sum).sort_values(by='general_sales', ascending=False)
genre_games['count'] = current_period['genre'].value_counts()
genre_games
# Out:
#               general_sales  count
# genre
# Action               321.87    766
# Shooter              232.98    187
# Sports               150.65    214
# Role-Playing         145.89    292
# Misc                  62.82    155
# Platform              42.63     74
# Racing                39.89     85
# Fighting              35.31     80
# Adventure             23.64    245
# Simulation            21.76     62
# Strategy              10.08     56
# Puzzle                 3.17     17

# %%
current_period.groupby('genre')['general_sales'].describe().sort_values(by='count', ascending=False)
# Out:
#               count      mean       std   min   25%    50%     75%    max
# genre
# Action        766.0  0.420196  1.253909  0.01  0.03  0.110  0.3375  21.05
# Role-Playing  292.0  0.499623  1.353164  0.01  0.06  0.125  0.3825  14.60
# Adventure     245.0  0.096490  0.216445  0.01  0.02  0.030  0.0700   1.66
# Sports        214.0  0.703972  1.219237  0.01  0.07  0.240  0.7650   8.58
# Shooter       187.0  1.245882  2.014107  0.01  0.14  0.450  1.4250  14.63
# Misc          155.0  0.405290  1.007985  0.01  0.03  0.100  0.3300   9.18
# Racing         85.0  0.469294  0.964101  0.01  0.05  0.120  0.3800   7.09
# Fighting       80.0  0.441375  1.048883  0.01  0.06  0.125  0.3225   7.55
# Platform       74.0  0.576081  0.806808  0.01  0.09  0.225  0.6275   4.32
# Simulation     62.0  0.350968  0.849163  0.01  0.03  0.100  0.2950   5.22
# Strategy       56.0  0.180000  0.279441  0.01  0.04  0.080  0.2325   1.67
# Puzzle         17.0  0.186471  0.325172  0.01  0.02  0.060  0.1100   1.19

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>❌ Молодец! По вопросу объема продаж все рассмотрел. Хорошие выводы, молодец, что не только описываешь увиденное, но и выскакзываешь свои мысли.
#
# Красный комментарий, поскольку не раскрыт вопрос "что можно сказать о самых прибыльных жанрах?"
# Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние или медианные продажи.
#
# Пожалуйста, доработай этот шаг.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"></div>
#
# По полученным данным можно сделать следующие выводы:
#
# 1. У наиболее популярных жанров огромная разница между средним значением продаж и минимальным/макимальным, что говорит о том, что какие-то проекты успешные, а какие-то, скорее-всего, имеют серьезные проблемы с окупаемостью.
# 2. Наиболее прибыльными оказались совсем не те жанры, которые лучше всего продаются. Ими стали: `Shooters`, `Adventure` и `Sports`.
#
# <div class="alert alert-info"></div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера 2:</b>✔️ Верный вывод.
# Только по прибыльности не очень показательно - согласись.. Тут бы график или такую же таблицу и отсортировать .
#
# Но цифры верные.</div>

# %% [markdown]
# ### Выводы по разделу

# %% [markdown]
# Наиболее популярными платформами на период с 2015 по 2016 годы являются `Xbox One` и `PS4`, что очевидно связано с превосходством компаний-создателей на игровом рынке, также неплохо себя показывает портативная консоль `Nintendo 3DS`, но и ее показатели не впечатляют.
#
# Характерный срок использования разных игровых платформ варьируется от 8 до 10 лет. Основными лидерами на рынке (как было упомянуто выше) остаются `Sony`, `Microsoft` и `Nintendo`, у которых выпускаются разные поколения, постепенно замещающие своих предшественников.
#
# Оценки пользователей и критиков не сильно влияют на продажи игр, но, остаается фактом: чем выше их оценки, тем больше вероятность, что игра продастя большим тиражем.
#
# Наиболее популярными жанрами игр являются экшн-игры, шутеры, спортивные симуляторы и ролевые игры. Наиболее впечатляющие показатели у жанров `Shooters`, `Adventure`, так как они оказались наиболее прибыльными жанрами в сфере игровой индустрии, несмотря на то, что по общим продажам располагаются только на 2 и 9! местах соответственно.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⚠️ Молодец, что подводишь итог. Нужно будет скорректировать, если в процессе доработок появятся изменения.
# </div>

# %% [markdown]
# <div class="alert alert-info"></div>
#
# Внес корректировки в вывод.
#
# <div class="alert alert-info"></div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера 2:</b>✔️ Готово</div>

# %% [markdown]
# ## Региональный портрет пользователя

# %% [markdown]
# Полную характеристику пользователей по региону представлю в конце раздела.

# %% [markdown]
# ### Топ-5 самых популярных платфор

# %% [markdown]
# #### Топ-5 по всему миру

# %%
stats_sales = current_period.pivot_table(index = 'platform', values = 'general_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='general_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#   platform  general_sales
# 0      PS4         314.14
# 1      PS3         181.43
# 2     XOne         159.32
# 3      3DS         143.25
# 4     X360         136.80

# %% [markdown]
# #### Пользователь региона `NA (North America)`

# %%
stats_sales = current_period.pivot_table(index = 'platform', values = 'na_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='na_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#   platform  na_sales
# 0      PS4    108.74
# 1     XOne     93.12
# 2     X360     81.66
# 3      PS3     63.50
# 4      3DS     38.20

# %% [markdown]
# Доли продаж между двумя конкурентами не сильно различаются, что связано с тем фактом, что `Xbox` - дочерняя компания `Microsoft` - американской компании, в связии с чем распространение их консолей в данном регионе наибольшее по сравнению с другими.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>✔️Здесь еще раз подчеркну - молодец, что видишь картину и рассматриваешь платформы в связке с компанией. </div>

# %% [markdown]
# #### Пользователь региона `EU (Europe)`

# %%
stats_sales = current_period.pivot_table(index = 'platform', values = 'eu_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='eu_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#   platform  eu_sales
# 0      PS4    141.09
# 1      PS3     67.81
# 2     XOne     51.59
# 3     X360     42.52
# 4      3DS     30.96

# %% [markdown]
# В Европе влияние `Microsoft` ощущается гораздо меньше, поэтому `Xbox One` располагается только на 3 месте, отставая от главного конкурента примерно в 2.7 раза.

# %% [markdown]
# #### Пользователь региона `JP (Japan)`

# %%
stats_sales = current_period.pivot_table(index = 'platform', values = 'jp_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='jp_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#   platform  jp_sales
# 0      3DS     67.81
# 1      PS3     23.35
# 2      PSV     18.59
# 3      PS4     15.96
# 4     WiiU     10.88

# %% [markdown]
# Япония является родной страной для таких компаний, как `Sony` и `Nintendo`. Из этого вытекает полное господство рынка игровыми платфорами от данных дыух производителей.

# %%
stats_sales = current_period.pivot_table(index = 'platform', values = ['na_sales', 'eu_sales', 'jp_sales', 'other_sales'], aggfunc=sum)
stats_sales['general_sales'] = current_period.pivot_table(index = 'platform', values = 'general_sales', aggfunc=sum)
stats_sales['eu%'] = round(stats_sales['eu_sales']/stats_sales['general_sales']*100, 2)
stats_sales['jp%'] = round(stats_sales['jp_sales']/stats_sales['general_sales']*100, 2)
stats_sales['na%'] = round(stats_sales['na_sales']/stats_sales['general_sales']*100, 2)
stats_sales['other%'] = round(stats_sales['other_sales']/stats_sales['general_sales']*100, 2)
stats_sales
# Out:
#           eu_sales  jp_sales  na_sales  other_sales  general_sales    eu%  \
# platform
# 3DS          30.96     67.81     38.20         6.28         143.25  21.61
# DS            0.85      0.00      0.57         0.12           1.54  55.19
# PC           25.36      0.00     11.11         2.96          39.43  64.32
# PS3          67.81     23.35     63.50        26.77         181.43  37.38
# PS4         141.09     15.96    108.74        48.35         314.14  44.91
# PSP           0.17      3.29      0.00         0.04           3.50   4.86
# PSV           6.10     18.59      5.04         3.26          32.99  18.49
# Wii           5.93      0.05      6.56         1.12          13.66  43.41
# WiiU         19.85     10.88     29.21         4.69          64.63  30.71
# X360         42.52      0.51     81.66        12.11         136.80  31.08
# XOne         51.59      0.34     93.12        14.27         159.32  32.38
#
#             jp%    na%  other%
# platform
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>❌ ОБЩЕЕ КО ВСЕМ РЕГИОНАМ
# Обрати, пожалуйста, внимание - нет ответа на вопрос.
#
# - Опишите различия в долях продаж.
#
# Здесь необходимо рассчитать в процентах и опираться при выводе на полученные цифры.</div>

# %% [markdown]
# <div class="alert alert-info"></div>
#
# Итак, сделаю вывод по поводу различия в долях продаж:
#
# 1. Продажи игр на американские консоли `Xbox 360` и `Xbox One` в Северной Америке составляют более, чем 58% от всего рынка. Также, рынок Северной Америки лидирует по продажам игр на японские консоли `Wii` и `WiiU`, опережая Европу на 4 и 15 процентов соотвественно.
# 2. Продажи игр на японские консоли `PS3` и `PS4` в Европе лучше, по сравнению с Северной Америкой, в особенности для консоли 8-го поколения - разница более 10%.
# 3. На японском рынке лучшего всего продаются портативные консоли, такие как `3DS` (47% от всего рынка), `PSP` (94% от всего рынка) и `PSV` (56% от всего рынка). Также на японском рынке совсем не предпочитают игры на американские консоли и персональные компьютеры.
#
# <div class="alert alert-info"></div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера 2:</b>⚠️ Вопрос о долях продаж можно понимать, конечно, по разному. В нашем случае "по горизонтали или вертикали". Рассматривая долю продаж на определенной платформе в долях по регионам, мы сравниваем регионы между собой.
# Здесь подразумевается портрет пользователя конкретного региона и потому  важно и "вертикальное" рассмотрение. Т.е доля продаж по платформам в каждом рассматриваемом регионе.
#
#
# </div>

# %% [markdown]
# ### Топ-5 самых популярных жанров

# %% [markdown]
# #### Топ-5 по всему миру

# %%
stats_sales = current_period.pivot_table(index = 'genre', values = 'general_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='general_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#           genre  general_sales
# 0        Action         321.87
# 1       Shooter         232.98
# 2        Sports         150.65
# 3  Role-Playing         145.89
# 4          Misc          62.82

# %% [markdown]
# #### Пользователь региона `NA (North America)`

# %% [markdown]
# Ранее уже упомяналось превосходство жанров `Action`, `Shooters` и `Sports`. В Америке и Европе данные совпадают, что связано с близостью увлечений и культур данных регионов.

# %%
stats_sales = current_period.pivot_table(index = 'genre', values = 'na_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='na_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#           genre  na_sales
# 0        Action    126.05
# 1       Shooter    109.74
# 2        Sports     65.27
# 3  Role-Playing     46.40
# 4          Misc     27.49

# %% [markdown]
# #### Пользователь региона `EU (Europe)`

# %%
stats_sales = current_period.pivot_table(index = 'genre', values = 'eu_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='eu_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#           genre  eu_sales
# 0        Action    118.13
# 1       Shooter     87.86
# 2        Sports     60.52
# 3  Role-Playing     36.97
# 4        Racing     20.19

# %% [markdown]
# #### Пользователь региона `JP (Japan)`

# %% [markdown]
# Япония вновь выделяется из всех рассматриваемых регионов. Наиболее распрсотраненные жанры - `Role-Playing`, `Role-Playing` и в том числе на 4 месте `Fighting`. Первый и последий жанры тесно связаны с менталитетом местных жителей и большим престрастием к боевым искусствам.

# %%
stats_sales = current_period.pivot_table(index = 'genre', values = 'jp_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='jp_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#           genre  jp_sales
# 0  Role-Playing     51.04
# 1        Action     40.49
# 2          Misc      9.20
# 3      Fighting      7.65
# 4       Shooter      6.61

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>✔️ Молодец! И хорошо, что замечая отличие японского рынка объясняешь это</div>

# %% [markdown]
# ### Влияние рейтинга ESRB на продажи в отдельном регионе

# %%
current_period['age_rating'] = current_period['age_rating'].fillna('Unknown')

# %% [markdown]
# #### По всему миру

# %%
stats_sales = current_period.pivot_table(index = ['platform', 'age_rating'], values = 'general_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='general_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#   platform age_rating  general_sales
# 0      PS4          M         125.91
# 1      3DS    Unknown          97.47
# 2      PS3          M          79.83
# 3     XOne          M          75.70
# 4      PS4    Unknown          68.20

# %% [markdown]
# #### Пользователь региона `NA (North America)`

# %%
stats_sales = current_period.pivot_table(index = ['platform', 'age_rating'], values = 'na_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='na_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#   platform age_rating  na_sales
# 0     XOne          M     44.92
# 1      PS4          M     42.81
# 2     X360          M     38.41
# 3      PS3          M     29.75
# 4      PS4    Unknown     23.77

# %% [markdown]
# #### Пользователь региона `EU (Europe)`

# %%
stats_sales = current_period.pivot_table(index = ['platform', 'age_rating'], values = 'eu_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='eu_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#   platform age_rating  eu_sales
# 0      PS4          M     58.43
# 1      PS3          M     31.75
# 2      PS4    Unknown     27.99
# 3      PS4          E     27.56
# 4     XOne          M     23.74

# %% [markdown]
# #### Пользователь региона `JP (Japan)`

# %%
stats_sales = current_period.pivot_table(index = ['platform', 'age_rating'], values = 'jp_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='jp_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#   platform age_rating  jp_sales
# 0      3DS    Unknown     52.40
# 1      PSV    Unknown     11.75
# 2      PS3    Unknown      8.96
# 3      3DS          E      6.94
# 4      PS3          T      6.87

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>❌На этапе обработки пропусков был совсем упущен вопрос о пропусках в rating . И сейчас игры без рейтинга оказались полностью исключенными из анализа. Но продажи именно этих игр могут указать на ключевое различие в регионах.Пожалуйста, подумай как включить их в анализ</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера 2:</b>✔️ Теперь игры без рейтинга учтены. отлично, что разобрались с этим моментом.</div>

# %% [markdown]
# ### Выводы по разделу

# %% [markdown]
# Рассматриваемый период 2013 -2016 года.
#
# **Пользователь региона `North America`**
#
# 1. Самыйе популярные игровые платформы - `PS4` и `Xbox One`.
# 2. Самые популярные игровые жанры - `Action` и `Shooters`.
# 3. Самый распространенный возрастной рейтинг - `M` (Mature — Для взрослых)
#
# Продажи игр на американские консоли Xbox 360 и Xbox One в Северной Америке составляют более, чем 58% от всего рынка. Также, рынок Северной Америки лидирует по продажам игр на японские консоли Wii и WiiU, опережая Европу на 4 и 15 процентов соотвественно.
#
# **Пользователь региона `Europe`**
#
# 1. Самыйе популярные игровые платформы - `PS4` и `PS3`.
# 2. Самые популярные игровые жанры - `Action` и `Shooters`.
# 3. Самый распространенный возрастной рейтинг - `M` (Mature — Для взрослых), на 3-ем месте распространены неоцененные игры, т.к. ESRB - американская компания, которая не занимается оценкой европейских и японских игр, которые в огромном количестве выходят на наиболее популярные игровые платформы в Европе.
#
# Продажи игр на японские консоли PS3 и PS4 в Европе лучше, по сравнению с Северной Америкой, в особенности для консоли 8-го поколения - разница более 10%.
#
# **Пользователь региона `Japan`**
#
# 1. Самыйе популярные игровые платформы - `3DS` и `PS3`.
# 2. Самые популярные игровые жанры - `Role-Playing` и `Action`.
# 3. Сложно что-то сказать про наиболее распространенный рейтинг игр, т.к. ESRB - американская компания, которая не занимается оценкой европейских и японских игр, которые в огромном количестве выходят на наиболее популярные игровые платформы в Японии.
#
# На японском рынке лучшего всего продаются портативные консоли, такие как 3DS (47% от всего рынка), PSP (94% от всего рынка) и PSV (56% от всего рынка). Также на японском рынке совсем не предпочитают игры на американские консоли и персональные компьютеры.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⚠️ Хорошо. Нужно будет скорректировать, если в процессе доработок появятся изменения.
# </div>

# %% [markdown]
# <div class="alert alert-info"></div>
#
# Внес корректировки в вывод.
#
# <div class="alert alert-info"></div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера 2:</b>✔️ Хорошо. Портреты составлены. Явное отлияие японского региона. Здесь можно добавить твое понимание - почему регион так кардинально отличается. Выводы ты делаешь хорошие, поэтому твои мысли в проекте только украсят его.</div>

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые?

# %% [markdown]
# **Нулевая гипотеза (H0)**: средние пользовательские рейтинги платформ Xbox One и PC совпадают.
#
# **Альтернативная двусторонняя гипотеза (H1)**: средние пользовательские рейтинги платформ Xbox One и PC не совпадают.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>✔️Гипотезы сформулированы верно</div>

# %%
alpha = .05

h0 = current_period[current_period['platform'] == 'PC']['user_score'].dropna()
h1 = current_period[current_period['platform'] == 'XOne']['user_score'].dropna()

results = st.ttest_ind(
    h0,
    h1,
    equal_var=True
)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.14012658403611647
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# На имеющихся данных, на уровне значимости 5% (уровне доверия 95%) нет оснований отвергнуть
# нулевую гипотезу в пользу альтернативы.

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action и Sports разные?

# %% [markdown]
# **Нулевая гипотеза (H0)**: средние пользовательские рейтинги жанров Action и Sports совпадают.
#
# **Альтернативная двусторонняя гипотеза (H1)**: средние пользовательские рейтинги жанров Action и Sports не совпадают.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>✔️Гипотезы сформулированы верно</div>

# %%
alpha = .05

h0 = current_period[current_period['genre'] == 'Action']['user_score'].dropna()
h1 = current_period[current_period['genre'] == 'Sports']['user_score'].dropna()

results = st.ttest_ind(
    h0,
    h1,
    equal_var=True
)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 1.0517832389140023e-27
# Отвергаем нулевую гипотезу

# %% [markdown]
# На имеющихся данных, на уровне значимости 5% (уровне доверия 95%) есть основания отвергнуть
# нулевую гипотезу в пользу альтернативы.

# %% [markdown]
# ### Выводы по разделу

# %% [markdown]
# Были проверены гипотезы:
#
# 1. На имеющихся данных, на уровне значимости 5% (уровне доверия 95%) нет оснований отвергнуть
# нулевую гипотезу в пользу альтернативы, но утверждать на основание этого, что средние пользовательские рейтинги платформ Xbox One и PC совпадают - нельзя.
#
# 2. Т.к. на имеющихся данных, на уровне значимости 5% (уровне доверия 95%) есть основания отвергнуть нулевую гипотезу в пользу альтернативы, сожно сказать, но утверждать на основание этого, что средние пользовательские рейтинги жанров Action и Sports не совпадают - нельзя.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера :</b>⚠️ ОБЩИЙ ПО ПРОВЕРКЕ ГИПОТЕЗ
#
# Молодец, ты верно формулируешь гипотезы, выводишь p-value, тест проводишь на данных без пропусков.
#
# Замечание к выводу. Дело в том, что проверкой гипотезы, мы не можем подтвердить ни нулевую, ни альтернативную.
#
#
# Вот здесь прекрасная статья, я думаю она поможет тебе с выводами и пригодится в будущем. Там есть алгоритм проведения теста.
#
# https://allatambov.github.io/psms/pdf/hypo-test.pdf
# </div>

# %% [markdown]
# <div class="alert alert-info"></div>
#
# Внес корректировки в вывод.
#
# <div class="alert alert-info"></div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера 2:</b>✔️ Вижу, что статья пригодилась. Молодец!</div>

# %% [markdown]
# ## Самые популярные игры (дополнительный раздел)

# %% [markdown]
# #### Топ-5 по всему миру за все время

# %%
stats_sales = df.pivot_table(index = 'name', values = 'general_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='general_sales', ascending=False).reset_index().loc[:9]
top_sales
# Out:
#                              name  general_sales
# 0                      Wii Sports          82.54
# 1              Grand Theft Auto V          56.58
# 2               Super Mario Bros.          45.31
# 3                          Tetris          35.84
# 4                  Mario Kart Wii          35.52
# 5               Wii Sports Resort          32.77
# 6        Pokemon Red/Pokemon Blue          31.38
# 7  Call of Duty: Modern Warfare 3          30.60
# 8           New Super Mario Bros.          29.80
# 9      Call of Duty: Black Ops II          29.40

# %% [markdown]
# #### Пользователь региона `NA (North America)`

# %%
stats_sales = current_period.pivot_table(index = 'name', values = 'na_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='na_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#                              name  na_sales
# 0              Grand Theft Auto V     23.84
# 1            Call of Duty: Ghosts     14.94
# 2       Call of Duty: Black Ops 3     12.25
# 3                       Minecraft     11.28
# 4  Call of Duty: Advanced Warfare     10.51

# %% [markdown]
# #### Пользователь региона `EU (Europe)`

# %%
stats_sales = current_period.pivot_table(index = 'name', values = 'eu_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='eu_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#                         name  eu_sales
# 0         Grand Theft Auto V     23.42
# 1                    FIFA 15     12.02
# 2                    FIFA 16     11.09
# 3                    FIFA 14     10.96
# 4  Call of Duty: Black Ops 3      9.49

# %% [markdown]
# #### Пользователь региона `JP (Japan)`

# %%
stats_sales = current_period.pivot_table(index = 'name', values = 'jp_sales', aggfunc=sum)
top_sales = stats_sales.sort_values(by='jp_sales', ascending=False).reset_index().loc[:4]
top_sales
# Out:
#                                         name  jp_sales
# 0                        Pokemon X/Pokemon Y      4.35
# 1                           Monster Hunter 4      3.44
# 2        Super Smash Bros. for Wii U and 3DS      3.24
# 3                  Yokai Watch 2 Ganso/Honke      3.18
# 4  Pokemon Omega Ruby/Pokemon Alpha Sapphire      3.10

# %% [markdown]
# #### Данные по моей любимой игре в жанре `Shooter`

# %%
df[df['name'] == 'Call of Duty: Black Ops']
# Out:
#                          name platform  year_of_release    genre  na_sales  \
# 32    Call of Duty: Black Ops     X360             2010  Shooter      9.70
# 41    Call of Duty: Black Ops      PS3             2010  Shooter      5.99
# 1398  Call of Duty: Black Ops      Wii             2010  Shooter      0.80
# 3391  Call of Duty: Black Ops       DS             2010  Shooter      0.50
#
#       eu_sales  jp_sales  other_sales  general_sales  critic_score  \
# 32        3.68      0.11         1.13          14.62          87.0
# 41        4.37      0.48         1.79          12.63          88.0
# 1398      0.45      0.00         0.12           1.37          80.0
# 3391      0.04      0.00         0.04           0.58          74.0
#
#       user_score age_rating
# 32           6.3          M
# 41           6.4          M
# 1398         5.8          M
# 3391         6.0          T

# %% [markdown]
# Несмотря на высокие оценки критиков, геймеры не высоко оценили данную игру.
#
# Мое мнение - ровно противоположно оценкам игроков, теплые воспоминания и высокое мнение о напряженной кампании с дополнительными режимами: сетевым и зомби, связывают меня с этой игрой. `Call of Duty: Black Ops` - это моя первая игра на геймпад на новенькую `Xbox 360 Slim`, в которую мы постоянно играли с братом и близкими друзьями. Все остальные игры были на Kinect, и один гоночный симулятор.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера 2:</b>✔️ Супер! Теперь вижу твое дополнение. Здорово, рассматривать данные, имея понимание и симпатию к предметной области.
#
# Японцы гоняют покемонов, остальные GTA (тоже провела там не один час). Твой любимый шутер - знаменит! (я не знаток именно по седьмой серии, но, игра, конечно на слуху)
# Ты уже проходил Atomic Heart? Я в восторге от атмосферы. Жаль времени на это совсем нет (((( Лучше проверю еще один проект )) </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Данный проект был посвящен анализу данных интернет-магазин «Стримчик», кторый предоставил исторические данные о продажах игр, оценках пользователей и экспертов, жанрах и платформах Задача состояла в том, чтобы выявить определяющие успешность игры закономерности, что позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# На первом этапе были изучены данные и сделаны первые выводы по возможным проблемам с датасетом.
#
# На втором этапе была произведена предобработка данных, а именно:
#
# 1. Обработаны и изучены пропущенные значения в столбцах.
# 2. Исправлены ошибочные типы данных в каждом столбце.
# 3. Добавлен столбец с суммарными продажами во всех регионах
#
# На третьем этапе был проведен исследовательский анализ, в ходе которого:
#
# 1. Построены гистограммы для разных параметров объектов и описаны основные зависимости.
# 2. Выбран актуальный период для исследования данных.
# 3. Изучены рост и падения игровых платформ за акутальный период.
# 4. Изучено влияние на продажи внутри одной популярной платформы отзывов пользователей и критиков.
# 5. Рассмотрено распределение игр по жанрам.
#
# На четвертом этапе были составлены портреты пользователей для разных регионов:
#
# 1. Определены самые популярные платформы и описаны различия в долях продаж.
# 2. Определены самые популярные жанры и объяснены зависимости от региона.
# 3. Изучено влияние рейтинга ESRB на продажи в отдельном регионе.
#
# Были проверены гипотезы:
#
# 1. На имеющихся данных, на уровне значимости 5% (уровне доверия 95%) нет оснований отвергнуть
# нулевую гипотезу в пользу альтернативы, но утверждать на основание этого, что средние пользовательские рейтинги платформ Xbox One и PC совпадают - нельзя.
#
# 2. Т.к. на имеющихся данных, на уровне значимости 5% (уровне доверия 95%) есть основания отвергнуть нулевую гипотезу в пользу альтернативы, сожно сказать, но утверждать на основание этого, что средние пользовательские рейтинги жанров Action и Sports не совпадают - нельзя.
#
# Наиболее популярными платформами на период с 2015 по 2016 годы являются `Xbox One` и `PS4`, что очевидно связано с превосходством компаний `Microsoft` и `Sony` на игровом рынке, также неплохо себя показывает портативная консоль `3DS`, японской комапнии `Nintendo`.
#
# **Характерный срок использования разных игровых платформ варьируется от 8 до 10 лет. Основными лидерами на рынке остаются `Sony`, `Microsoft` и `Nintendo`, у которых выпускаются разные поколения, постепенно замещающие своих предшественников.**
#
# Оценки пользователей и критиков не сильно влияют на продажи игр, но, остаается фактом: чем выше их оценки, тем больше вероятность, что игра продастя большим тиражем.
#
# Наиболее популярными жанрами игр являются экшн-игры, шутеры, спортивные симуляторы и ролевые игры. Наиболее впечатляющие показатели у жанров `Shooters`, `Adventure`, так как они оказались наиболее прибыльными жанрами в сфере игровой индустрии, несмотря на то, что по общим продажам располагаются только на 2 и 9! местах соответственно.
#
# В ходе исследования были составлены портреты для пользователей разных регионов:
#
# 1. **Пользователь региона `North America`**
#
# >Самыйе популярные игровые платформы - `PS4` и `Xbox One`.
# >Самые популярные игровые жанры - `Action` и `Shooters`.
# >Самый распространенный возрастной рейтинг - `M` (`Mature` — Для взрослых).
#
# >Продажи игр на американские консоли `Xbox 360` и `Xbox One` в Северной Америке составляют более, чем 58% от всего рынка. Также, рынок Северной Америки лидирует по продажам игр на японские консоли Wii и WiiU, опережая Европу на 4 и 15 процентов соотвественно.
#
# 2. **Пользователь региона `Europe`**
#
# >Самыйе популярные игровые платформы - `PS4` и `PS3`.
# >Самые популярные игровые жанры - `Action` и `Shooters`.
# >Самый распространенный возрастной рейтинг - `M` (`Mature` — Для взрослых), на 3-ем месте распространены неоцененные игры, т.к. `ESRB` - американская компания, которая не занимается оценкой европейских и японских игр, которые в огромном количестве выходят на наиболее популярные игровые платформы в Европе.
#
# >Продажи игр на японские консоли `PS3` и `PS4` в Европе лучше, по сравнению с Северной Америкой, в особенности для консоли 8-го поколения - разница более 10%.
#
# 3. **Пользователь региона `Japan`**
#
# >Самыйе популярные игровые платформы - `3DS` и `PS3`.
# >Самые популярные игровые жанры - `Role-Playing` и `Action`.
# >Сложно что-то сказать про наиболее распространенный рейтинг игр, т.к. `ESRB` - американская компания, которая не занимается оценкой европейских и японских игр, которые в огромном количестве выходят на наиболее популярные игровые платформы в Японии.
#
# >На японском рынке лучшего всего продаются портативные консоли, такие как `3DS` (47% от всего рынка), `PSP` (94% от всего рынка) и `PSV` (56% от всего рынка). Также на японском рынке совсем не предпочитают игры на американские консоли и персональные компьютеры.
#
# Таким образом, можно сделать вывод, что **владельцам интернет-магазина «Стримчик» стоит сдедать ставку на 2 консоли `Xbox One` и `PS4`. Наиболее популярными для нашего региона будут игры жанров: `Action`, `Shooters`, `Sports`, `Role-Playing` и `Racing`. Обратить внимание стоит на игры с взрослым возрастным рейтингом, но и подростковые игры не стоит отбрасывать.**

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера :</b>⚠️ С учетом всех доработок, пожалуйста, проверь общий вывод. Вывод по структуре хороший, включены и цели исследования и результаты, полученные в ходе исследования и рекомендация для владельцев магазина.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера 2:</b>✔️Молодец корретировки вижу. Отличный вывод . Стримчик с таким аналитиком имеет все шансы на успех!</div>

# %% [markdown]
# <div style="border:solid lightblue 3px; padding: 20px">
# <b>Общий комментарий ревьюера:</b>
#
# Даниил, ты молодец и проделал большую работу с первым сборным проектом. Проект отлично оформлен - здесь и использование автоматического оглавления, и использование возможностей markdown. Работать с таким проектом - одно удовольствие. Спасибо тебе! Ты внимательно относишься к данным, видишь процессы стоящие за ними, что очень важно. Используешь различные инструменты. У тебя получается хороший проект! Жаль, что какая-то ошибка в коде по твоему дополнительному шагу не позволила ознакомиться с этим. Но думаю ты исправишь и сможем посмотреть.
# Нам осталось немного доработать и сделать твое исследование еще лучше. Я постаралась подробно прокомментировать и, надеюсь, у тебя быстро все получится.
#
#
# Буду ждать твой проект! Удачи!
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Хотел поблагодарить Вас за столь понятную и конструктивную проверку моей местами невнимательной работы! Если у Вас есть какие-то интересные ссылки или советы по возможносятм развития в сфере DS, буду благодарен за обратную связь!</div>

# %% [markdown]
# <div style="border:solid lightblue 3px; padding: 20px">
# <b>Общий комментарий ревьюера 2:</b>
#
# Даниил, ты очень добросовестно доработал проект. И твой первый Сборный - принят. Передохни и впереди очень много интересного!
#
# ссылка на книги https://progerlib.ru/data-science-books
#
#
#
# Удачи тебе! Было здорово работать с тобой!
# </div>

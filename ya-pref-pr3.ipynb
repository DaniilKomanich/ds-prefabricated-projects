# %% [markdown]
# <h1> Комментарий тимлида </h1>
#
# 👋 **Приветствую, Даниил!**
#
# ✨ Поздравляю с началом работы над финальным проектом!
#
# Меня зовут Арсен Абдулин и я буду твоим ревьювером. Предлагаю общаться на «ты», если не против =)
#
# При проверке работ я пишу следующие комментарии:
#
# <div class="alert alert-success">
# <b>✔️ Зеленым цветом</b> отмечены удачные решения.</div>
#
# <div class="alert alert-warning">
# <b>⚠️ Желтым цветом</b> я отметил пункты, которые в следующий раз можно сделать по-другому. Одно-два таких замечания в проекте допускается, но если их много — проект следует доработать. </div>
#
# <div class="alert alert-danger">
# <b>🚫 Красным цветом</b> отмечены критические замечания, которые необходимо поправить, чтобы принять проект. </div>
#
# Если какие-то моменты в задании для тебя были непонятны и у тебя есть ко мне вопросы — смело спрашивай 😊 Также ты можешь доработать места, где есть желтые комментарии в проекте (однако, это не обязательно).
#
# Предлагаю работать в диалоге: если ты решишь что-то поменять по моим рекомендациям — пиши об этом (выбери для своих комментариев определенный цвет - так мне будет легче увидеть изменения). Пожалуйста не перемещай, не изменяй и не удаляй мои комментарии. Все это поможет сделать проверку твоего проекта оперативнее.
#
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Пример комментария. </div>

# %% [markdown]
# # Прогнозирование оттока клиентов оператора связи

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.

# %% [markdown]
# ## Цель проекта

# %% [markdown]
# Построить модель для прогнозирования оттока клиентов, доведя метрику `ROC-AUC` до значения не менее `0.85`.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Хорошо, когда есть описание проекта и поставлена цель — так постороннему человеку будет проще ознакомиться!
#
# </div>

# %% [markdown]
# ## Описание услуг оператора связи

# %% [markdown]
# Оператор предоставляет два основных типа услуг:
#
# 1. Стационарную телефонную связь. Возможно подключение телефонного аппарата к нескольким линиям одновременно.
# 2. Интернет. Подключение может быть двух типов: через телефонную линию (`DSL`, от англ. `digital subscriber line`, «цифровая абонентская линия») или оптоволоконный кабель (`Fiber optic`).
#
# Также доступны такие услуги:
# 1. Интернет-безопасность: антивирус (`DeviceProtection`) и блокировка небезопасных сайтов (`OnlineSecurity`);
# 2. Выделенная линия технической поддержки (`TechSupport`);
# 3. Облачное хранилище файлов для резервного копирования данных (`OnlineBackup`);
# 4. Стриминговое телевидение (`StreamingTV`) и каталог фильмов (`StreamingMovies`).
#
#
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года. Доступны различные способы расчёта и возможность получения электронного чека.

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Цель-проекта" data-toc-modified-id="Цель-проекта-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Цель проекта</a></span></li><li><span><a href="#Описание-услуг-оператора-связи" data-toc-modified-id="Описание-услуг-оператора-связи-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Описание услуг оператора связи</a></span></li><li><span><a href="#Используемые-библиотеки" data-toc-modified-id="Используемые-библиотеки-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Используемые библиотеки</a></span></li><li><span><a href="#Предварительный-анализ-данных" data-toc-modified-id="Предварительный-анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Предварительный анализ данных</a></span><ul class="toc-item"><li><span><a href="#Краткое-описание-данных" data-toc-modified-id="Краткое-описание-данных-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Краткое описание данных</a></span></li><li><span><a href="#Исследование-датасета-contract_new.csv" data-toc-modified-id="Исследование-датасета-contract_new.csv-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Исследование датасета <code>contract_new.csv</code></a></span></li><li><span><a href="#Исследование-датасета-personal_new.csv" data-toc-modified-id="Исследование-датасета-personal_new.csv-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Исследование датасета <code>personal_new.csv</code></a></span></li><li><span><a href="#Исследование-датасета-internet_new.csv" data-toc-modified-id="Исследование-датасета-internet_new.csv-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Исследование датасета <code>internet_new.csv</code></a></span></li><li><span><a href="#Исследование-датасета-phone_new.csv" data-toc-modified-id="Исследование-датасета-phone_new.csv-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Исследование датасета <code>phone_new.csv</code></a></span></li><li><span><a href="#План-работ" data-toc-modified-id="План-работ-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>План работ</a></span></li><li><span><a href="#Выводы-по-предварительному-анализу-данных" data-toc-modified-id="Выводы-по-предварительному-анализу-данных-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Выводы по предварительному анализу данных</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Краткое-описание-этапа" data-toc-modified-id="Краткое-описание-этапа-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Краткое описание этапа</a></span></li><li><span><a href="#Объединение-датасетов-в-один" data-toc-modified-id="Объединение-датасетов-в-один-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Объединение датасетов в один</a></span></li><li><span><a href="#Проверка-на-наличие-явных-и-неявных-дубликатов" data-toc-modified-id="Проверка-на-наличие-явных-и-неявных-дубликатов-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Проверка на наличие явных и неявных дубликатов</a></span></li><li><span><a href="#Обработка-пропущенных-значений" data-toc-modified-id="Обработка-пропущенных-значений-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Обработка пропущенных значений</a></span></li><li><span><a href="#Привидение-к-требуемому-типу-данных" data-toc-modified-id="Привидение-к-требуемому-типу-данных-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Привидение к требуемому типу данных</a></span></li><li><span><a href="#Выводы-по-предобработке-данных" data-toc-modified-id="Выводы-по-предобработке-данных-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Выводы по предобработке данных</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Краткое-описание-этапа" data-toc-modified-id="Краткое-описание-этапа-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Краткое описание этапа</a></span></li><li><span><a href="#Изучение-корреляции-представленных-данных" data-toc-modified-id="Изучение-корреляции-представленных-данных-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Изучение корреляции представленных данных</a></span><ul class="toc-item"><li><span><a href="#Количественные-признаки" data-toc-modified-id="Количественные-признаки-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>Количественные признаки</a></span></li><li><span><a href="#Категориальные-признаки" data-toc-modified-id="Категориальные-признаки-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>Категориальные признаки</a></span></li></ul></li><li><span><a href="#Выводы-по-исследовательскому-анализу-данных" data-toc-modified-id="Выводы-по-исследовательскому-анализу-данных-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Выводы по исследовательскому анализу данных</a></span></li></ul></li><li><span><a href="#Построение-и-обучение-модели-машинного-обучения" data-toc-modified-id="Построение-и-обучение-модели-машинного-обучения-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Построение и обучение модели машинного обучения</a></span><ul class="toc-item"><li><span><a href="#Краткое-описание-этапа" data-toc-modified-id="Краткое-описание-этапа-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Краткое описание этапа</a></span></li><li><span><a href="#Подготовка-признаков" data-toc-modified-id="Подготовка-признаков-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Подготовка признаков</a></span><ul class="toc-item"><li><span><a href="#Разбиение-признаков" data-toc-modified-id="Разбиение-признаков-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span>Разбиение признаков</a></span></li><li><span><a href="#Кодирование-данных" data-toc-modified-id="Кодирование-данных-8.2.2"><span class="toc-item-num">8.2.2&nbsp;&nbsp;</span>Кодирование данных</a></span></li><li><span><a href="#Масштабирование-признаков" data-toc-modified-id="Масштабирование-признаков-8.2.3"><span class="toc-item-num">8.2.3&nbsp;&nbsp;</span>Масштабирование признаков</a></span></li></ul></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#LogisticRegression" data-toc-modified-id="LogisticRegression-8.3.1"><span class="toc-item-num">8.3.1&nbsp;&nbsp;</span><code>LogisticRegression</code></a></span></li><li><span><a href="#RandomForrestClassifier" data-toc-modified-id="RandomForrestClassifier-8.3.2"><span class="toc-item-num">8.3.2&nbsp;&nbsp;</span><code>RandomForrestClassifier</code></a></span></li><li><span><a href="#CatBoostClassifier" data-toc-modified-id="CatBoostClassifier-8.3.3"><span class="toc-item-num">8.3.3&nbsp;&nbsp;</span><code>CatBoostClassifier</code></a></span></li></ul></li><li><span><a href="#Исследование-важности-признаков-лучшей-модели" data-toc-modified-id="Исследование-важности-признаков-лучшей-модели-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Исследование важности признаков лучшей модели</a></span></li><li><span><a href="#Проверка-наилучшей-модели-на-тестовой-выборке" data-toc-modified-id="Проверка-наилучшей-модели-на-тестовой-выборке-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>Проверка наилучшей модели на тестовой выборке</a></span></li><li><span><a href="#Выводы-по-работе-с-моделями-машинного-обучения" data-toc-modified-id="Выводы-по-работе-с-моделями-машинного-обучения-8.6"><span class="toc-item-num">8.6&nbsp;&nbsp;</span>Выводы по работе с моделями машинного обучения</a></span></li></ul></li><li><span><a href="#Отчет-по-проектной-деятельности" data-toc-modified-id="Отчет-по-проектной-деятельности-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Отчет по проектной деятельности</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий тимлида:</b> В целом по плану работ все хорошо, только оформи пожалуйста все это в отдельной ячейке и назови План работ.
#
# Хочу отметить, что после обучения всех моделей, лучшую модель необходимо проверить на тестовой выборке.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Исправил согласно требованиям. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Хорошо 👍
#
# </div>

# %% [markdown]
# ## Используемые библиотеки

# %%
# !pip install -q phik
# !pip install -U -q scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import catboost as cat
import phik
import time
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from sklearn.metrics import roc_auc_score, roc_curve, auc

import warnings
warnings.filterwarnings("ignore")

RANDOM_STATE = 280823

# %% [markdown]
# ## Предварительный анализ данных

# %% [markdown]
# ### Краткое описание данных

# %% [markdown]
# Данные состоят из файлов, полученных из разных источников:
# - `contract_new.csv` — информация о договоре;
# - `personal_new.csv` — персональные данные клиента;
# - `internet_new.csv` — информация об интернет-услугах;
# - `phone_new.csv` — информация об услугах телефонии.
#
# Во всех файлах столбец `customerID` содержит код клиента.
#
# **Информация о договорах актуальна на 1 февраля 2020.**

# %%
try:
    contract = pd.read_csv('/datasets/contract_new.csv')
    personal = pd.read_csv('/datasets/personal_new.csv')
    internet = pd.read_csv('/datasets/internet_new.csv')
    phone = pd.read_csv('/datasets/phone_new.csv')
except:
    contract = pd.read_csv('C:/Users/dkoma/Downloads/final_project/contract_new.csv')
    personal = pd.read_csv('C:/Users/dkoma/Downloads/final_project/datasets/personal_new.csv')
    internet = pd.read_csv('C:/Users/dkoma/Downloads/final_project/datasets/internet_new.csv')
    phone = pd.read_csv('C:/Users/dkoma/Downloads/final_project/datasets/phone_new.csv')

# %% [markdown]
# ### Исследование датасета `contract_new.csv`

# %% [markdown]
# Данный датасет содержит информацию о договоре.

# %%
contract.head(10)
# Out:
#    customerID   BeginDate     EndDate            Type PaperlessBilling  \
# 0  7590-VHVEG  2020-01-01          No  Month-to-month              Yes
# 1  5575-GNVDE  2017-04-01          No        One year               No
# 2  3668-QPYBK  2019-10-01          No  Month-to-month              Yes
# 3  7795-CFOCW  2016-05-01          No        One year               No
# 4  9237-HQITU  2019-09-01          No  Month-to-month              Yes
# 5  9305-CDSKC  2019-03-01          No  Month-to-month              Yes
# 6  1452-KIOVK  2018-04-01          No  Month-to-month              Yes
# 7  6713-OKOMC  2019-04-01          No  Month-to-month               No
# 8  7892-POOKP  2017-07-01          No  Month-to-month              Yes
# 9  6388-TABGU  2014-12-01  2017-05-01        One year               No
#
#                PaymentMethod  MonthlyCharges TotalCharges
# 0           Electronic check           29.85        31.04
# 1               Mailed check           56.95      2071.84
# ...

# %% [markdown]
# **Описание признаков в `contract_new.csv`:**
#
# 1. `customerID` - индивидуальный код клиента;
# 2. `BeginDate` - дата начала пользования услугами;
# 3. `EndDate` - дата окончания пользования услугами;
# 4. `Type` - тип оплаты: ежемесячный, годовой или на два года;
# 5. `PaperlessBilling` - безналичный расчет;
# 6. `PaymentMethod` - способ оплаты;
# 7. `MonthlyCharges` - ежемесячные траты на услуги;
# 8. `TotalCharges` - общая сумма, потраченная на услуги.

# %%
contract.info()
print('\nРазмер датасета', contract.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB
#
# Размер датасета (7043, 8)

# %% [markdown]
# Датасет состоит из 8 столбцов и 7043 строк.

# %%
contract.describe(include='all').T
# Out:
#                    count unique               top  freq       mean        std  \
# customerID          7043   7043        8782-NUUOL     1        NaN        NaN
# BeginDate           7043     77        2014-02-01   366        NaN        NaN
# EndDate             7043     67                No  5942        NaN        NaN
# Type                7043      3    Month-to-month  3875        NaN        NaN
# PaperlessBilling    7043      2               Yes  4171        NaN        NaN
# PaymentMethod       7043      4  Electronic check  2365        NaN        NaN
# MonthlyCharges    7043.0    NaN               NaN   NaN  64.761692  30.090047
# TotalCharges        7043   6658                      11        NaN        NaN
#
#                     min   25%    50%    75%     max
# customerID          NaN   NaN    NaN    NaN     NaN
# BeginDate           NaN   NaN    NaN    NaN     NaN
# EndDate             NaN   NaN    NaN    NaN     NaN
# Type                NaN   NaN    NaN    NaN     NaN
# ...

# %% [markdown]
# **Выводы**
#
# 1. Данный датасет содержит информацию о `77` уникальных датах заключения контракта, и `67` - завершения.
# 2. Наиболее полпулярный тип и способ оплаты - ежемесячный и онлайн.
# 3. `TotalCharges` имеет неправильный тип данных `object`, необходимо исправить на численный.
# 4. В данном датасете `MonthlyCharges` и `TotalCharges` (после исправления) - количественные, остальные - категориальные.

# %% [markdown]
# ### Исследование датасета `personal_new.csv`

# %% [markdown]
# Данный датасет содержит персональные данные клиента.

# %%
personal.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No
# 5  9305-CDSKC  Female              0      No         No
# 6  1452-KIOVK    Male              0      No        Yes
# 7  6713-OKOMC  Female              0      No         No
# 8  7892-POOKP  Female              0     Yes         No
# 9  6388-TABGU    Male              0      No        Yes

# %% [markdown]
# **Описание признаков в `personal_new.csv`:**
#
# 1. `customerID` - индивидуальный код клиента:
# 2. `gender` - пол клиента;
# 3. `SeniorCitizen` - наличие пенсионного статуса по возрасту;
# 4. `Partner` - наличие супруга(-и);
# 5. `Dependents` - наличие иждевенцев.

# %%
personal.info()
print('\nРазмер датасета', personal.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB
#
# Размер датасета (7043, 5)

# %% [markdown]
# Датасет состоит из 5 столбцов и 7043 строк.

# %%
personal.describe(include='all').T
# Out:
#                 count unique         top  freq      mean       std  min  25%  \
# customerID       7043   7043  8782-NUUOL     1       NaN       NaN  NaN  NaN
# gender           7043      2        Male  3555       NaN       NaN  NaN  NaN
# SeniorCitizen  7043.0    NaN         NaN   NaN  0.162147  0.368612  0.0  0.0
# Partner          7043      2          No  3641       NaN       NaN  NaN  NaN
# Dependents       7043      2          No  4933       NaN       NaN  NaN  NaN
#
#                50%  75%  max
# customerID     NaN  NaN  NaN
# gender         NaN  NaN  NaN
# SeniorCitizen  0.0  0.0  1.0
# Partner        NaN  NaN  NaN
# Dependents     NaN  NaN  NaN

# %% [markdown]
# **Выводы**
#
# В данном датасете `SeniorCitizen` - количественный, остальные - категориальные.

# %% [markdown]
# ### Исследование датасета `internet_new.csv`

# %% [markdown]
# Данный датасет содержит информацию об интернет-услугах.

# %%
internet.head(10)
# Out:
#    customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# 3  7795-CFOCW             DSL            Yes           No              Yes
# 4  9237-HQITU     Fiber optic             No           No               No
# 5  9305-CDSKC     Fiber optic             No           No              Yes
# 6  1452-KIOVK     Fiber optic             No          Yes               No
# 7  6713-OKOMC             DSL            Yes           No               No
# 8  7892-POOKP     Fiber optic             No           No              Yes
# 9  6388-TABGU             DSL            Yes          Yes               No
#
#   TechSupport StreamingTV StreamingMovies
# 0          No          No              No
# 1          No          No              No
# ...

# %% [markdown]
# **В качестве признаков в `internet_new.csv` выступают различные типы предоставляемых услуг по обеспечению Интернет соединения.**

# %%
internet.info()
print('\nРазмер датасета', internet.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5517 non-null   object
#  1   InternetService   5517 non-null   object
#  2   OnlineSecurity    5517 non-null   object
#  3   OnlineBackup      5517 non-null   object
#  4   DeviceProtection  5517 non-null   object
#  5   TechSupport       5517 non-null   object
#  6   StreamingTV       5517 non-null   object
#  7   StreamingMovies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB
#
# Размер датасета (5517, 8)

# %% [markdown]
# Датасет состоит из 8 столбцов и 5517 строк.

# %%
internet.describe(include='all').T
# Out:
#                  count unique          top  freq
# customerID        5517   5517   2921-XWDJH     1
# InternetService   5517      2  Fiber optic  3096
# OnlineSecurity    5517      2           No  3498
# OnlineBackup      5517      2           No  3088
# DeviceProtection  5517      2           No  3095
# TechSupport       5517      2           No  3473
# StreamingTV       5517      2           No  2810
# StreamingMovies   5517      2           No  2785

# %% [markdown]
# **Выводы**
#
# 1. Согласно данным можно сделать вывод, что только `5517` пользователей из `7043` пользуются интернетом.
# 2. Наиболее полпулярный способом предоставления Интернет соединения - оптоволокно.
# 3. В данном датасете все признаки категориальные.

# %% [markdown]
# ### Исследование датасета `phone_new.csv`

# %% [markdown]
# Данный датасет содержит информацию об услугах телефонии.

# %%
phone.head(10)
# Out:
#    customerID MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes
# 5  7892-POOKP           Yes
# 6  6388-TABGU            No
# 7  9763-GRSKD            No
# 8  7469-LKBCI            No
# 9  8091-TTVAX           Yes

# %% [markdown]
# **Описание признаков в `phone_new.csv`:**
#
# 1. `customerID` - индивидуальный код клиента:
# 2. `MultipleLines` - наличие возможности ведения параллельных линий во время звонка.

# %%
phone.info()
print('\nРазмер датасета', phone.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB
#
# Размер датасета (6361, 2)

# %% [markdown]
# Датасет состоит из 2 столбцов и 6361 строк.

# %%
phone.describe(include='all').T
# Out:
#               count unique         top  freq
# customerID     6361   6361  8782-NUUOL     1
# MultipleLines  6361      2          No  3390

# %% [markdown]
# **Выводы**
#
# Согласно данным можно сделать вывод, что только `6361` пользовать из `7043` пользуются телефоном.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> Предварительный анализ данных выполнен успешно! Видно, что потребуется дальнейшая предобработка.
#
# </div>

# %% [markdown]
# ### План работ

# %% [markdown]
# 1. Провести предобработку данных, в ходе которого необходимо:
# - Объединенить датасеты в один;
# - Произвести проверку на наличие явных и неявных дубликатов;
# - Обработать пропущенные значения;
# - Привидести данные к требуемому типу данных.
# 2. Выполнить исследовательский анализ данных, включающий анализ количественных и категориальных признаков, в том числе, изучение корреляции представленных данных.
#
#
# 3. Построить и обучить модели машинного обучения, при этом:
# - Подготовить признаки;
# - Обучить и проанализировать результаты обучения моделей;
# - Произвести проверку наилучшей модели на тестовой выборке.
# 4. Составить общие выводы по результатам выполнения проекта.

# %% [markdown]
# ### Выводы по предварительному анализу данных

# %% [markdown]
# 1. В качестве исследуемых данных предосталено `4` датасета:
# - `contract`, содержащий `7043` строк и `8` столбцов;
# - `personal`, содержащий `7043` строк и `5` столбцов;
# - `internet`, содержащий `5517` строк и `8` столбцов;
# - `phone`, содержащий `6361` строк и `2` столбца.
# 2. Встречаются как количественные, так и категориальные признаки. Перед обучением моделей машинного обучения необходимо преобразовать их в количественные.
# 3. В качестве целевого признака выбран столбец `EndDate` из датасета `contract_new.csv`, который необходимо преобразовать в количественный.
# 4. Составлен план будущих работ по проекту.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий тимлида:</b> План работ принят, можно приступать к основному проекту.
#
# Сохрани пожалуйста наши с тобой комментарии, а проект продолжай в этом же файле. Успехов!
# </div>

# %% [markdown]
# <h1> Комментарий ревьювера </h1>
#
# <div class="alert alert-success">
#
# 👋 Даниил, привет еще раз! Это снова Арсен Абдулин — и я буду делать ревью основного проекта.
#
# Давай посмотрим, что получилось.
#
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Краткое описание этапа

# %% [markdown]
# В ходе данного этапа необходимо:
#
# 1. Объединить датасеты для упрощения предобработки и исследовательского анализа данных.
# 2. Проверить датасеты на наличие дубликатов.
# 3. Обработать пропущенные значения.
# 4. Привести данные к соответствующему типу данных.

# %% [markdown]
# ### Объединение датасетов в один

# %% [markdown]
# Перед объединением таблиц можно отдельными признаками обозначить услуги, которыми выбрал пользователь. В исследовательском анализе данные признаки помогут выявить дополнительные зависимости между разными признаками.

# %%
internet['InternetUser'] = 'Yes'
phone['PhoneUser'] = 'Yes'

# %% [markdown]
# Необходимо объединить исходные даттасеты в один.

# %%
df = (contract
      .merge(personal, how="left", on="customerID")
      .merge(internet, how="left", on="customerID")
      .merge(phone, how="left", on="customerID"))

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Отлично, датасет собран успешно!
#
# </div>

# %%
df.head(10)
# Out:
#    customerID   BeginDate     EndDate            Type PaperlessBilling  \
# 0  7590-VHVEG  2020-01-01          No  Month-to-month              Yes
# 1  5575-GNVDE  2017-04-01          No        One year               No
# 2  3668-QPYBK  2019-10-01          No  Month-to-month              Yes
# 3  7795-CFOCW  2016-05-01          No        One year               No
# 4  9237-HQITU  2019-09-01          No  Month-to-month              Yes
# 5  9305-CDSKC  2019-03-01          No  Month-to-month              Yes
# 6  1452-KIOVK  2018-04-01          No  Month-to-month              Yes
# 7  6713-OKOMC  2019-04-01          No  Month-to-month               No
# 8  7892-POOKP  2017-07-01          No  Month-to-month              Yes
# 9  6388-TABGU  2014-12-01  2017-05-01        One year               No
#
#                PaymentMethod  MonthlyCharges TotalCharges  gender  \
# 0           Electronic check           29.85        31.04  Female
# ...

# %%
df.info()
print('\nРазмер датасета', df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
#  8   gender            7043 non-null   object
#  9   SeniorCitizen     7043 non-null   int64
#  10  Partner           7043 non-null   object
#  11  Dependents        7043 non-null   object
#  12  InternetService   5517 non-null   object
#  13  OnlineSecurity    5517 non-null   object
#  14  OnlineBackup      5517 non-null   object
#  15  DeviceProtection  5517 non-null   object
# ...

# %% [markdown]
# Объединенный датасет состоит из 20 столбцов и 7043 строк.

# %% [markdown]
# Все категориальные данные приведем к нижнему регистру для удобства поиска дубликатов.

# %%
cols_to_low = ['customerID', 'EndDate', 'Type', 'PaperlessBilling', 'PaymentMethod', 'gender', 'Partner', 'Dependents', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'InternetUser', 'MultipleLines', 'PhoneUser']
for col in cols_to_low:
    df[col] = df[col].str.lower()

# %%
df.head()
# Out:
#    customerID   BeginDate EndDate            Type PaperlessBilling  \
# 0  7590-vhveg  2020-01-01      no  month-to-month              yes
# 1  5575-gnvde  2017-04-01      no        one year               no
# 2  3668-qpybk  2019-10-01      no  month-to-month              yes
# 3  7795-cfocw  2016-05-01      no        one year               no
# 4  9237-hqitu  2019-09-01      no  month-to-month              yes
#
#                PaymentMethod  MonthlyCharges TotalCharges  gender  \
# 0           electronic check           29.85        31.04  female
# 1               mailed check           56.95      2071.84    male
# 2               mailed check           53.85       226.17    male
# 3  bank transfer (automatic)           42.30       1960.6    male
# 4           electronic check           70.70        353.5  female
#
#    SeniorCitizen  ... InternetService OnlineSecurity OnlineBackup  \
# 0              0  ...             dsl             no          yes
# ...

# %% [markdown]
# ### Проверка на наличие явных и неявных дубликатов

# %%
print('Количество явных дубликатов:', df.duplicated().sum())
# Out:
# Количество явных дубликатов: 0

# %%
print('Уникальные значения столбцов оюъединенного датасета\n')
for column in df.columns:
    print(column, '->', df[column].sort_values().unique(), '\n')
# Out:
# Уникальные значения столбцов оюъединенного датасета
#
# customerID -> ['0002-orfbo' '0003-mknfe' '0004-tlhlj' ... '9992-ujoel' '9993-lhieb'
#  '9995-hotoh']
#
# BeginDate -> ['2013-10-01' '2013-11-01' '2013-12-01' '2014-01-01' '2014-02-01'
#  '2014-03-01' '2014-04-01' '2014-05-01' '2014-06-01' '2014-07-01'
#  '2014-08-01' '2014-09-01' '2014-10-01' '2014-11-01' '2014-12-01'
#  '2015-01-01' '2015-02-01' '2015-03-01' '2015-04-01' '2015-05-01'
#  '2015-06-01' '2015-07-01' '2015-08-01' '2015-09-01' '2015-10-01'
#  '2015-11-01' '2015-12-01' '2016-01-01' '2016-02-01' '2016-03-01'
#  '2016-04-01' '2016-05-01' '2016-06-01' '2016-07-01' '2016-08-01'
#  '2016-09-01' '2016-10-01' '2016-11-01' '2016-12-01' '2017-01-01'
#  '2017-02-01' '2017-03-01' '2017-04-01' '2017-05-01' '2017-06-01'
#  '2017-07-01' '2017-08-01' '2017-09-01' '2017-10-01' '2017-11-01'
#  '2017-12-01' '2018-01-01' '2018-02-01' '2018-03-01' '2018-04-01'
#  '2018-05-01' '2018-06-01' '2018-07-01' '2018-08-01' '2018-09-01'
# ...

# %% [markdown]
# По выведенной информации можно сделать выводы, что необходимо:
#
# - Исследовать столбец `TotalCharges` и заменить '   ' (пробелы) подходящими значениями.
# - Заполнить пропуски в столбцах со значениями `NaN`.

# %% [markdown]
# Так как у `TotalCharges` еще и неправильный тип данных, было принято решение заменить пробелы на `NaN`, а тип данных - на `float64`.

# %%
df['TotalCharges'] = pd.to_numeric(contract['TotalCharges'], errors='coerce')
df['TotalCharges'].sort_values().unique()
# Out:
# array([  19.05,   19.1 ,   19.19, ..., 9218.88, 9221.38,     nan])

# %% [markdown]
# ### Обработка пропущенных значений

# %%
print('Количество пропусков в данных')
df.isna().sum()
# Out:
# Количество пропусков в данных
# customerID             0
# BeginDate              0
# EndDate                0
# Type                   0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges         0
# TotalCharges          11
# gender                 0
# SeniorCitizen          0
# Partner                0
# Dependents             0
# InternetService     1526
# OnlineSecurity      1526
# OnlineBackup        1526
# DeviceProtection    1526
# TechSupport         1526
# StreamingTV         1526
# StreamingMovies     1526
# InternetUser        1526
# MultipleLines        682
# PhoneUser            682
# dtype: int64

# %% [markdown]
# В столбце `TotalCharges` 11 пропусков, которые необходимо обработать.

# %%
df[df['TotalCharges'].isna()]
# Out:
#       customerID   BeginDate EndDate      Type PaperlessBilling  \
# 488   4472-lvygi  2020-02-01      no  two year              yes
# 753   3115-czmzd  2020-02-01      no  two year               no
# 936   5709-lvoeq  2020-02-01      no  two year               no
# 1082  4367-nuyao  2020-02-01      no  two year               no
# 1340  1371-dwpaz  2020-02-01      no  two year               no
# 3331  7644-omvmy  2020-02-01      no  two year               no
# 3826  3213-vvolg  2020-02-01      no  two year               no
# 4380  2520-sgtta  2020-02-01      no  two year               no
# 5218  2923-arzlg  2020-02-01      no  one year              yes
# 6670  4075-wkniu  2020-02-01      no  two year               no
# 6754  2775-sefee  2020-02-01      no  two year              yes
#
#                   PaymentMethod  MonthlyCharges  TotalCharges  gender  \
# 488   bank transfer (automatic)           52.55           NaN  female
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Хорошо, что обратил внимание на пустые строки в признаке TotalCharges!
#
# Как рекомендация, пропуски можно заменить месячными значениями платежей
#
# </div>

# %% [markdown]
# Все пропуски в столбце `TotalCharges` соответствуют дате выгрузки датасетов, поэтому можно сделать вывод, что первый платеж еще не был произведен. Пропуски можно заполнить согласно выбранному типу оплаты `за два года`. Для этого необходимо выяснить сколько стоит тариф на два года для соответствующего набора услуг у других пользователей.
#
# Тем не менее, обязательность заполнения данных пропусков ставится под сомнение в связи с такими фактами:
# - пропуски составляют только `0.00156 %` от всего датасета;
# - рассчет стоимости тарифа зависит как от выбранных услуг, так и от года оформления контракта. Как мы знаем, с каждым годом стоимость на абонентские услуги только растет.

# %% [markdown]
# Было принято решение избавиться от этих строк.

# %%
df = df[~df['TotalCharges'].isna()].reset_index(drop=True)

# %% [markdown]
# Оставшиеся пропуски соответствуют случаю, когда пользователь не подключил дополнительные услуги, например, подключение Интернета или возможность ведения параллельных линий во время звонка. Данные пропуски можно заполнить категориальным значением `no`.

# %%
df[['InternetService', 'OnlineSecurity', 'OnlineBackup', 
    'DeviceProtection', 'TechSupport', 'StreamingTV', 
    'StreamingMovies', 'InternetUser', 'MultipleLines', 'PhoneUser']] = df[['InternetService', 'OnlineSecurity','OnlineBackup', 
                                               'DeviceProtection', 'TechSupport', 'StreamingTV', 
                                               'StreamingMovies', 'InternetUser', 'MultipleLines', 'PhoneUser']].fillna('no')

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Согласен, можно заполнить пропуски таким образом
#
# </div>

# %%
print('Количество пропусков в данных')
df.isna().sum()
# Out:
# Количество пропусков в данных
# customerID          0
# BeginDate           0
# EndDate             0
# Type                0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# InternetUser        0
# MultipleLines       0
# PhoneUser           0
# dtype: int64

# %% [markdown]
# ### Привидение к требуемому типу данных

# %% [markdown]
# Осталось два столбца с неправильным типом данных: `EndDate` и `BeginDate`. Требуемый тип данных `datetime64`.

# %% [markdown]
# Столбец `EndDate` содержит категориальное значение `no`. Имеет смысл заменить его на даты выгрузки датасетов для удобства проведения исследовательского анализа и обучения моделей машинного обучения в дальнейшем.

# %%
df.loc[df['EndDate'] == 'no', 'EndDate'] = '2020-02-01'

# %%
df['BeginDate'] = pd.to_datetime(df['BeginDate'], format='%Y-%m-%d')
df['EndDate'] = pd.to_datetime(df['EndDate'], format='%Y-%m-%d')

# %%
df.head(10)
# Out:
#    customerID  BeginDate    EndDate            Type PaperlessBilling  \
# 0  7590-vhveg 2020-01-01 2020-02-01  month-to-month              yes
# 1  5575-gnvde 2017-04-01 2020-02-01        one year               no
# 2  3668-qpybk 2019-10-01 2020-02-01  month-to-month              yes
# 3  7795-cfocw 2016-05-01 2020-02-01        one year               no
# 4  9237-hqitu 2019-09-01 2020-02-01  month-to-month              yes
# 5  9305-cdskc 2019-03-01 2020-02-01  month-to-month              yes
# 6  1452-kiovk 2018-04-01 2020-02-01  month-to-month              yes
# 7  6713-okomc 2019-04-01 2020-02-01  month-to-month               no
# 8  7892-pookp 2017-07-01 2020-02-01  month-to-month              yes
# 9  6388-tabgu 2014-12-01 2017-05-01        one year               no
#
#                PaymentMethod  MonthlyCharges  TotalCharges  gender  \
# 0           electronic check           29.85         31.04  female
# 1               mailed check           56.95       2071.84    male
# ...

# %% [markdown]
# В качестве дополнительных признаков можно добавить два столбца:
#
# - с длительностью пользования услугами оператора связи;
# - с информацией о том, пользуетя ли пользователь услугами оператора связи до сих пор, либо же ушёл.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Хорошо, так мы получим целевой и дополнительный признаки!
#
# </div>

# %%
df['ServiceDuration'] = (df['EndDate'] - df['BeginDate']).dt.days
df['CurrentUser'] = 0
df.loc[df['EndDate'] < '2020-02-01', 'CurrentUser'] = 1

# %%
df.head(30)
# Out:
#     customerID  BeginDate    EndDate            Type PaperlessBilling  \
# 0   7590-vhveg 2020-01-01 2020-02-01  month-to-month              yes
# 1   5575-gnvde 2017-04-01 2020-02-01        one year               no
# 2   3668-qpybk 2019-10-01 2020-02-01  month-to-month              yes
# 3   7795-cfocw 2016-05-01 2020-02-01        one year               no
# 4   9237-hqitu 2019-09-01 2020-02-01  month-to-month              yes
# 5   9305-cdskc 2019-03-01 2020-02-01  month-to-month              yes
# 6   1452-kiovk 2018-04-01 2020-02-01  month-to-month              yes
# 7   6713-okomc 2019-04-01 2020-02-01  month-to-month               no
# 8   7892-pookp 2017-07-01 2020-02-01  month-to-month              yes
# 9   6388-tabgu 2014-12-01 2017-05-01        one year               no
# 10  9763-grskd 2019-01-01 2020-02-01  month-to-month              yes
# 11  7469-lkbci 2018-10-01 2020-02-01        two year               no
# ...

# %%
df.describe(include='all').T
# Out:
#                    count unique                  top  freq      first  \
# customerID          7032   7032           8908-slfcj     1        NaT
# BeginDate           7032     76  2014-02-01 00:00:00   366 2013-10-01
# EndDate             7032     67  2020-02-01 00:00:00  5931 2014-06-01
# Type                7032      3       month-to-month  3875        NaT
# PaperlessBilling    7032      2                  yes  4168        NaT
# PaymentMethod       7032      4     electronic check  2365        NaT
# MonthlyCharges    7032.0    NaN                  NaN   NaN        NaT
# TotalCharges      7032.0    NaN                  NaN   NaN        NaT
# gender              7032      2                 male  3549        NaT
# SeniorCitizen     7032.0    NaN                  NaN   NaN        NaT
# Partner             7032      2                   no  3639        NaT
# Dependents          7032      2                   no  4933        NaT
# ...

# %% [markdown]
# ### Выводы по предобработке данных

# %% [markdown]
# 1. Для удобства дальнейшей работы с данными исходные датасеты объединены в один-общий по столбцу `customerID`.
#
# 2. После предобработки в датасете не осталось пропусков, все столбцы соответствуют реальному типу данных.
#
# 3. Из датасета удалено менее, чем `0.002 %` данных.
#
# 4. В качестве дополнительных признаков добавлены признаки с длительностью оказания услуг оператором связи в днях и с указанием текущего состояния пользования услугами оператора связи.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Краткое описание этапа

# %% [markdown]
# В ходе данного этапа необходимо:
#
# 1. Исследовать количественные и категориальные признаки.
# 2. Исследовать распределение пользователей по признаков.
# 3. Проверить возможные аномальные значения.

# %% [markdown]
# ### Изучение корреляции представленных данных

# %% [markdown]
# #### Количественные признаки

# %% [markdown]
# Исследуем количественные признаки:

# %%
numeric_cols = ['MonthlyCharges','TotalCharges','ServiceDuration']

# %% [markdown]
# **Матрица корреляции**

# %%
corr = df[numeric_cols].corr()
corr.style.background_gradient(cmap='Spectral')
# Out:
# <style  type="text/css" >
# #T_893e4_row0_col0,#T_893e4_row1_col1,#T_893e4_row2_col2{
#             background-color:  #5e4fa2;
#             color:  #f1f1f1;
#         }#T_893e4_row0_col1,#T_893e4_row0_col2,#T_893e4_row2_col0{
#             background-color:  #9e0142;
#             color:  #f1f1f1;
#         }#T_893e4_row1_col0{
#             background-color:  #f9fcb5;
#             color:  #000000;
#         }#T_893e4_row1_col2{
#             background-color:  #79c9a5;
#             color:  #000000;
#         }#T_893e4_row2_col1{
#             background-color:  #fbfdb8;
#             color:  #000000;
#         }</style><table id="T_893e4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MonthlyCharges</th>        <th class="col_heading level0 col1" >TotalCharges</th>        <th class="col_heading level0 col2" >ServiceDuration</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# Матрица корреляции количественных признаков показывает, что суммарные траты пользователей сильно зависят от времени пользования услугами оператора связи. Данный факт является одним из наиболее логичных, так как чем дольше человек пользуется услугами, тем больше ему надо за них платить. Сильная корреляция более, чем в `82 %`, что говорит о мультиколлинеарности признака `TotalCharges.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Все правильно, в данном случае действительно имеет место мультиколлинеарность
#
# </div>

# %% [markdown]
# Исследуем количественные признаки:

# %%
def numeric_stats(df):
    cols = 3
    rows = 2
    plt.figure(figsize=(16, 8))
    idx = 0
    for col in numeric_cols:
        idx += 1 
        plt.subplot(rows, cols, idx)
        plt.hist(df[col])
        plt.title(col)
    plt.show()

# %%
numeric_stats(df)

# %% [markdown]
# По гистограммам можно сделать следующие выводы:
#
# - Пик ежемесячных трат приходится на плату около `20` у.е., что говорит о том, что большинство абнентов пользуется только малой частью услуг;
# - Несмотря на то, что присутствует и большое количество абнентов платящих более `80` у.е., долго услугами оператора они не пользуются, на что указывает, как гистограмма признака `TotalCharges`, так и - `ServiceDuration`.
# - По гистограмме признака `ServiceDuration` можно сказать, что услугами оператора связи воспользовалось огрмное количество новых пользователей, в то время, как постоянные пользователи постепенно уменьшаются, кроме наиболее лояльных.

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 6))
          
sns.boxplot(x='CurrentUser', y='MonthlyCharges', data=df, ax=axs[0])
axs[0].set_title('Ежемесячные траты на услуги', fontsize=14)
plt.grid(color = 'lightblue', linewidth = 1, linestyle=':')

sns.boxplot(x='CurrentUser', y='TotalCharges', data=df, ax=axs[1])
axs[1].set_title('Общие траты за услуги', fontsize=16)
plt.grid(color = 'lightblue', linewidth = 1, linestyle=':')

sns.boxplot(x='CurrentUser', y='ServiceDuration', data=df, ax=axs[2])
axs[2].set_title('Длительность пользования услугами', fontsize=16)
plt.grid(color = 'lightblue', linewidth = 1, linestyle=':')

# %% [markdown]
# **Оставшиеся пользователи**

# %%
df.loc[df['CurrentUser'] == 0]['ServiceDuration'].describe()
# Out:
# count    5931.000000
# mean      895.338560
# std       716.588322
# min        31.000000
# 25%       245.000000
# 50%       702.000000
# 75%      1523.000000
# max      2314.000000
# Name: ServiceDuration, dtype: float64

# %% [markdown]
# **Ушедшие пользователи**

# %%
df.loc[df['CurrentUser'] == 1]['ServiceDuration'].describe()
# Out:
# count    1101.000000
# mean      924.863760
# std       458.771309
# min        28.000000
# 25%       577.000000
# 50%       915.000000
# 75%      1249.000000
# max      2129.000000
# Name: ServiceDuration, dtype: float64

# %% [markdown]
# Из полученных диаграмм и данных можно сделать следующие выводы:
#
# 1. **Ежемесячные траты на услуги**
#
# Медиана ушедших пользователей больше, чем у текущих. Тем не менее, разброс значений для ушедших и оставшихся пользователи одинаковый (от `20` до `120` у.е.)
#
# 2. **Общие траты за услуги**
#
# Медианное значение ушедших пользователей также больше, чем у отсавшихся. Для текущих пользователей услугами оператора связи присутствуют выбросы, для ушедших выбросы в основном попадают в разброс нориальных значений для оставшихся пользователей. Разброс значений для текущих: от `0` до значений около `7500` у.е., у ушедших - от `0` до значений около `7000` у.е.
#
# 3. **Длительность пользования услугами**
#
# Медиана пользования для ушедших пользователей составляет около `900` дней, в то время, как у текущих - только около `700` дней. Размах значений для ушедших клиентов небольшой (от `600` до `1300` дней) по сравнению с текущими (от `250` до `1500` дней).
#
# Можно утвердить, что новые пользователи тратят большую сумму на услуги, так как предпочитают короткие периоды (ежемесячную опалту). Интересно, что пользователи уходят в основном спустя чуть более, чем `900` дней, что составляет достаточно продолжительный период в чуть менее, чем `2,5` года.

# %% [markdown]
# Необходимо изучить графики распределения пользователей по признакам.

# %%
def kdeplot(df, figsize, x, y, suptitle, hue = None):
    fig, ax = plt.subplots(figsize = figsize)
    fig.suptitle(suptitle, fontsize = 14)
    kdeplt = sns.kdeplot(df, hue = hue) 
    kdeplt.grid(color = 'lightblue', linewidth = 1, linestyle=':')
    kdeplt.set_xlabel(x, fontsize = 12)
    kdeplt.set_ylabel(y, fontsize = 12)
    return kdeplt

# %%
kdeplot(df['ServiceDuration'], 
        figsize = (15, 5), 
        x = 'Количество дней пользования: 1 = ушел, 0 = пользуется',
        y = 'Плотность распределения',
        suptitle = 'Распределение количества дней пользования услугами',
        hue = df['CurrentUser'])
plt.show()

# %% [markdown]
# Из графика распределения видно, что пиковое значение для текущих пользователей - около `100` дней и `2100` дней, для ушедших - около `900` дней.

# %%
kdeplot(df['MonthlyCharges'],
        figsize = (15, 5), 
        x = 'Размер платежа для разных: 1 = ушел, 0 = пользуется',
        y = 'Плотность распределения',
        suptitle = 'Распределение величины ежемесячного платежа', 
        hue = df['CurrentUser'])
plt.show()

# %% [markdown]
# Из графика распределения видно, что пиковое значени ежемесячного платежа для текущих пользователей составляет около `20` у.е. Для ушедших пользователей пик приходится на `100` у.е.

# %%
kdeplot(df['TotalCharges'],
        figsize = (15, 5), 
        x = 'Размер платежа для разных: 1 = ушел, 0 = пользуется',
        y = 'Плотность распределения',
        suptitle = 'Распределение величины общего платежа', 
        hue = df['CurrentUser'])
plt.show()

# %% [markdown]
# Из графика распределения видно, что пиковое значени общего платежа для текущих пользователей составляет около `500` у.е., как и для ушедших пользователей.

# %% [markdown]
# Исходя из плотности распределения пользователей данных графиков, можно сделать вывод, что как текущие, так и ушедшие пользователи предпочитали ежемесячный тип оплаты. Ушедших пользователй с большим общим платежом гораздо меньше, чем текущих, что может говорить о том, что они редко оплачивали ежегодно или раз в 2 года.

# %%
kdeplot(df['CurrentUser'],
        figsize = (15, 5), 
        x = '0 = пользуется 1 = ушел', y = '',
        suptitle = 'Распределение пользователей телефонными услугами', 
        hue = df['PhoneUser'])

kdeplot(df['CurrentUser'],
        figsize = (15, 5), 
        x = '0 = пользуется 1 = ушел', y = '',
        suptitle = 'Распределение пользователей Интернет услугами', 
        hue = df['InternetUser'])

plt.show()

# %% [markdown]
# Пользователи, подключившие Интернет услуги чаще рассторгают сотрудничество с оператором связи, чем пользователи, подключившие телефонные услуги.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Хороший анализ данных! Здорово, что исследовал различия для групп ушедших и оставшихся клиентов
#
# ***
#
# Еще нужно только помнить, что влияние различных факторов на целевую переменную, это гипотеза, и нужно использовать методы проверки гипотез. Но это уже отдельная работа =)
#
# </div>

# %% [markdown]
# #### Категориальные признаки

# %% [markdown]
# **Матрица корреляции**

# %%
phik_matrix = df.phik_matrix(['MonthlyCharges', 'TotalCharges', 'SeniorCitizen', 'ServiceDuration', 'CurrentUser'])
phik_matrix.style.background_gradient(cmap='Spectral')
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# Согласно данной матрице можно наблюдать мультиколлинеарность между следующими признаками:
#
# 1. `ServiceDuration` --- `BeginDate`;
# 2. `Type` --- `BeginDate`;
# 3. `InternetService`, `InternetUser`, `StreamingMovies`, `StreamingTV` --- `MonthlyCharges`;
# 4. `ServiceDuration` --- `TotalCharges` (ранее уже обозначил).

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Здорово, что применил библиотеку phik для анализа корреляции смешанного набора признаков!
#
# Что касается корреляции категориальных признаков, то это пока что пища для размышлений, не стоит сразу по этому условию удалять признаки. Данная корреляция может быть нелинейная, и на линейные модели это не повлияет.
#
# </div>

# %% [markdown]
# Исследуем категориальные признаки:

# %%
category_cols = ['Type', 'PaperlessBilling', 'PaymentMethod', 'gender', 'Partner', 'Dependents',
                 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 
                 'TechSupport', 'StreamingTV', 'StreamingMovies', 'MultipleLines',]

# %%
def category_stats(df):
    cols = 3
    rows = 7
    plt.figure(figsize=(20, 30))
    idx = 0
    for col in category_cols:
        idx+=1
        plt.subplot(rows, cols, idx)
        plt.hist(df[col].sort_values())
        plt.title(col)
    plt.show()

# %%
category_stats(df)

# %% [markdown]
# По гистограммам можно сделать следующие выводы:
#
# - Наиболее популярный тип оплаты - помесячный и безналичный с электронным чеком.
# - Наиболее популярный способ подключения - оптоволоконный.
# - Все дополнительные услуги не пользуются популярностью у пользователей.

# %% [markdown]
# ### Выводы по исследовательскому анализу данных

# %% [markdown]
# 1. Пик ежемесячных тратах приходится на плату около `20` у.е., а значит большинство абнентов пользуется только малой частью услуг;
# 2. Услугами оператора связи воспользовалось огромное количество новых пользователей, в то время, как постоянные пользователи постепенно уменьшаются, кроме наиболее лояльных.
# 3. Текущие и ушедшие пользователи предпочитали ежемесячный тип оплаты. Ушедших пользователй с большим общим платежом гораздо меньше, чем текущих, что может говорить о том, что они редко оплачивали ежегодно или раз в 2 года.
# 4. Пользователи, подключившие Интернет услуги чаще рассторгают сотрудничество с оператором связи, чем пользователи, подключившие телефонные услуги.
# 5. Наиболее популярный тип оплаты - помесячный и безналичный с электронным чеком.
# 6. Наиболее популярный способ подключения - оптоволоконный.
# 7. Все дополнительные услуги не пользуются популярностью у пользователей.
# 8. Обнаружены мультиколлинеарные признаки, от которых нужно избавиться при подготовки признаков к обучению моделей машинного обучения.

# %% [markdown]
# ## Построение и обучение модели машинного обучения

# %% [markdown]
# ### Краткое описание этапа

# %% [markdown]
# В ходе данного этапа необходимо:
#
# 1. Разбить данные на тренировочную и тестовую выборки.
# 2. Закодировать категориальные признаки.
# 3. Провести масштабирование количественных признаков.
# 4. Обучить модели машинного обучения с метрикой качества `ROC-AUC` > `0.85`
# 5. Исследовать влияние признаков на значение `ROC-AUC`.
# 5. Наилучшую модель проверить на тестовой выборке.

# %% [markdown]
# ### Подготовка признаков

# %% [markdown]
# #### Разбиение признаков

# %% [markdown]
# В качестве целевого признака выбран `CurrentUser`, определяющий остался ли клиент `0` или же перестал пользоваться услушами оператора связи `1`.

# %%
target = df['CurrentUser']
print('Размер целевого признаков:', target.shape)
# Out:
# Размер целевого признаков: (7032,)

# %% [markdown]
# В оставшихся данных необходимо избавиться от признаков, которые могут испортить предсказания моделей машинного обучения. К таким признакам относятся:
#
# 1. `customerID` - индивидуальный код клиента;
# 2. `BeginDate`, `EndDate` - даты начала и окончания пользования услугами;
# 3. `TotalCharges` - общая сумма, потраченная на услуги;
# 4. `InternetUser`, `PhoneUser`  - информация о пользовании телефонными или Интернет услугами.

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Я бы не стал удалять категориальные признаки (написал об этом комментарий к корреляции phik)
#
# </div>

# %%
features = df.drop(['CurrentUser', 'customerID', 'BeginDate', 'EndDate', 'TotalCharges', 
                     'InternetUser', 'PhoneUser'], axis=1)  

print('Размер признаков:', features.shape)
# Out:
# Размер признаков: (7032, 17)

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Type              7032 non-null   object
#  1   PaperlessBilling  7032 non-null   object
#  2   PaymentMethod     7032 non-null   object
#  3   MonthlyCharges    7032 non-null   float64
#  4   gender            7032 non-null   object
#  5   SeniorCitizen     7032 non-null   int64
#  6   Partner           7032 non-null   object
#  7   Dependents        7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  MultipleLines     7032 non-null   object
# ...

# %% [markdown]
# Необходимо разбить данные на тренировочную и тестовую выборки в соотношении `3:1`, с учетом сохранения соотношения классов, представленных в объединенном датасете.

# %%
features_train, features_test, target_train, target_test = train_test_split(features, target, stratify=target, test_size=0.25, random_state=RANDOM_STATE)

# %% [markdown]
# #### Кодирование данных

# %% [markdown]
# Категориальные данные необходимо закодировать в количественные, для этого можно применить `OHE` кодирование.

# %%
category_cols = features_train.select_dtypes(include='object').columns.to_list()

# %%
encoder_ohe = OneHotEncoder(drop='first', handle_unknown='ignore', sparse=False)
encoder_ohe.fit(features_train[category_cols])
features_train[encoder_ohe.get_feature_names_out()] = encoder_ohe.transform(features_train[category_cols])
features_train = features_train.drop(category_cols, axis=1)

# %%
print('Размер тренировочной выборки после кодирования:', features_train.shape)
# Out:
# Размер тренировочной выборки после кодирования: (5274, 21)

# %%
features_test[encoder_ohe.get_feature_names_out()] = encoder_ohe.transform(features_test[category_cols])
features_test = features_test.drop(category_cols, axis=1)

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера:</b> Энкодер не должен обучаться на тестовой выборке, только на train
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Исправил согласно требованиям. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Хорошо, замечание поправлено!
#
# </div>

# %%
print('Размер тестовой выборки после кодирования:', features_test.shape)
# Out:
# Размер тестовой выборки после кодирования: (1758, 21)

# %% [markdown]
# #### Масштабирование признаков

# %%
numeric_cols.remove('TotalCharges')

# %% [markdown]
# Необходимо провести масштабирование количественных признаков.

# %%
scaler = StandardScaler()
features_train_lr = features_train.copy()
features_test_lr = features_test.copy()

features_train_lr[numeric_cols] = scaler.fit_transform(features_train_lr[numeric_cols])
features_test_lr[numeric_cols] = scaler.transform(features_test_lr[numeric_cols])

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера:</b> Такое же замечание для Scaler, на тестовой выборке только операция transform
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Исправил согласно требованиям. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Хорошо 👍
#
# </div>

# %% [markdown]
# ### Обучение моделей

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера:</b> Тестовую выборку используем только в заключительной части, для проверки лучшей модели
#
# Достаточно посчитать результат через
#
#     model_lr.best_score_
#
# Остальные расчеты лишние
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Оставил время выполнения ячейки в качестве ориентира по возможной длительности выполнения проекта. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Хорошо, эта информация не будет лишней 👌
#
# </div>

# %% [markdown]
# #### `LogisticRegression`

# %%
start = time.time()

param_grid = {
    'C': range(1, 5, 1),
    'solver': ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'],
    'max_iter': range(150, 251, 50),
    'tol': [0.001, 0.01, 0.1]
}

model = LogisticRegression(random_state=RANDOM_STATE, class_weight='balanced', n_jobs=-1)
model_lr = GridSearchCV(model, param_grid, cv=5, scoring='roc_auc')
model_lr.fit(features_train_lr, target_train)

best_params_lr = model_lr.best_params_
print('\nЛучшие параметры для LogisticRegression', best_params_lr)
auc_train_lr = model_lr.best_score_
print('ROC-AUC на тренировочной выборке:', auc_train_lr)

lr_time_train = time.time() - start 
print('\nВремя выполнения ячейки:', round(lr_time_train/60), 'мин')
# Out:
# Лучшие параметры для LogisticRegression {'C': 2, 'max_iter': 150, 'solver': 'saga', 'tol': 0.1}
# ROC-AUC на тренировочной выборке: 0.7558770521776144
#
# Время выполнения ячейки: 11 мин

# %% [markdown]
# #### `RandomForrestClassifier`

# %%
start = time.time()

param_grid = {
    'max_depth': range(5, 16, 5),
    'min_samples_split': range(1, 5, 1),
    'min_samples_leaf': range(5, 21, 2),
    'n_estimators': [50, 100, 150], 
}

model = RandomForestClassifier(random_state=RANDOM_STATE, class_weight='balanced')
model_rf = GridSearchCV(model, param_grid, cv=5, scoring='roc_auc')
model_rf.fit(features_train, target_train)

best_params_rf = model_rf.best_params_
print('\nЛучшие параметры для RandomForestClassifier', best_params_rf)
auc_train_rf = model_rf.best_score_
print('ROC-AUC на тренировочной выборке:', auc_train_rf)

rf_time_train = time.time() - start 
print('\nВремя выполнения ячейки:', round((rf_time_train/60), 2), 'мин')
# Out:
# Лучшие параметры для RandomForestClassifier {'max_depth': 15, 'min_samples_leaf': 13, 'min_samples_split': 2, 'n_estimators': 100}
# ROC-AUC на тренировочной выборке: 0.8170798040697427
#
# Время выполнения ячейки: 6.46 мин

# %% [markdown]
# #### `CatBoostClassifier`

# %%
start = time.time()

param_grid = {
    'learning_rate': [0.01, 0.05, 0.1],
    'iterations': range(800, 1001, 100),
    'depth': range(1, 12, 5),
    'l2_leaf_reg': [1, 3, 5]
}

model = CatBoostClassifier(random_state=RANDOM_STATE, verbose=False)
model_cb = GridSearchCV(model, param_grid, cv=5, scoring='roc_auc')
model_cb.fit(features_train, target_train)

best_params_cb = model_cb.best_params_
print('\nЛучшие параметры для CatBoostClassifier', best_params_cb)
auc_train_cb = model_cb.best_score_
print('ROC-AUC на тренировочной выборке:', auc_train_cb)

cb_time_train = time.time() - start 
print('\nВремя выполнения ячейки:', round((cb_time_train/60), 2), 'мин')
# Out:
# Лучшие параметры для CatBoostClassifier {'depth': 6, 'iterations': 1000, 'l2_leaf_reg': 1, 'learning_rate': 0.05}
# ROC-AUC на тренировочной выборке: 0.9130795389072741
#
# Время выполнения ячейки: 95.99 мин

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Качество модели Catboost на кросс-валидации очень хорошее, а на тестировании явная проблема
#
# Проверь, что выборки train и test выглядят одинаково
#
# Для модели Catboost лучше также не масштабировать числовые признаки
#
# ***
#
# По структуре проекта, сначала нужно написать вывод о лучшей модели, а затем проверить модель на тестовой выборке
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>ℹ️ Комментарий студента: </b> Исправил согласно предложениям. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Обучение моделей выполнено правильно, результаты получились хорошие!
#
# </div>

# %% [markdown]
# ### Исследование важности признаков лучшей модели

# %% [markdown]
# Наилучшее значение метрики `ROC-AUC` показала модель `CatBoostClassifier`. Исселудем влияние признаков на результат обучения.

# %%
model = model_cb.best_estimator_.fit(features_train, target_train)
feature_importance = model.feature_importances_
sorted_idx = np.argsort(feature_importance)
fig = plt.figure(figsize=(15, 8))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), np.array(features_train.columns)[sorted_idx])
plt.title('Важность признаков', fontsize = 14)
plt.show()

# %% [markdown]
# Согласно диаграмме можно сделать вывод, что наиболее важными признаками оказались `ServiceDuration` и `MonthlyCharges`.

# %% [markdown]
# ### Проверка наилучшей модели на тестовой выборке

# %% [markdown]
# Лучшей моделью оказался `CatBoostClassifier`. Необходимо проверить его качество на тестовой выборке.

# %%
model_cb = CatBoostClassifier(random_state=RANDOM_STATE, verbose=False, depth = 6, iterations = 900, l2_leaf_reg = 1, learning_rate = 0.05)
model_cb.fit(features_train, target_train)
predict_proba_cb = model_cb.predict_proba(features_test)[:, 1]
roc_auc_cb = roc_auc_score(target_test, predict_proba_cb)
print('ROC-AUC на тестовой выборке:', roc_auc_cb)
# Out:
# ROC-AUC на тестовой выборке: 0.9282486360571323

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Отличный результат на тестировании, поздравляю!
#
# </div>

# %% [markdown]
# Дополнительно построим кривую ошибок `ROC`.

# %%
fpr, tpr, thresholds = roc_curve(target_test, predict_proba_cb)
roc_auc = auc(fpr, tpr)
fig = plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='darkorange', label='area = %0.2f' % roc_auc_cb)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC-кривая', fontsize = 14)
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Выводы по работе с моделями машинного обучения

# %% [markdown]
# 1. Для обучения моделей машинного обучения данные были рабиты на выборки: тестовую и тренировочную. Категориальные данные закодированы, а для количественных произведено масштабирование.
# 2. Для расчет метрики качества `ROC-AUC` обучено `3` модели `LogisticRegression`, `RandomForrestClassifier` и `CatBoostClassifier`. Наилучший результат на тренировочной выборке в `0.913` показала последняя модель, несмотря на наиболее долгий подбор параметров.
# 3. Для модели `CatBoostClassifier` исследована важность признаков, используемых для обучения. Также она была проверена на тестовой выборке с наилучшими гиперапараметрами `{'depth': 6, 'iterations': 1000, 'l2_leaf_reg': 1, 'learning_rate': 0.05}`. Значение полученной метрики `ROC-AUC` составило `0.928`.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Вот небольшие статьи по метрикам в машинном обучении, если заинтересует:
#
# https://habr.com/ru/company/ods/blog/328372/
#
# https://habr.com/ru/company/jetinfosystems/blog/420261/
#
# </div>

# %% [markdown]
# <font color=blue>
# <b> ✔️ 👍 Заключение ревьювера:</b> Даниил, у тебя хорошая работа, было приятно делать проверку!
#
# Тебе практически удалось справиться с выпускным проектом, поздравляю! Данные из разных таблиц собраны в один датафрейм, удалены аномалии, заполнены пропуски, получены новые признаки, а ненужные признаки удалены. Рассмотрено несколько моделей и сделан перебор параметров. Могу отметить самостоятельность и аналитический подход в выполнении проекта!
#
# Положительные моменты:
#
# - грамотное и понятное оформление кода;
#
# - аналитический подход — исследованы распределения признаков;
#
# - новые признаки сгенерированы правильно, лишние удалены;
#
# - рассмотрено несколько моделей, выполнен перебор гиперпараметров, удалось достичь высокого значения метрики ROC-AUC.
#
# Сейчас есть несколько важных замечаний:
#
# - поправить кодирование и масштабирование признаков;
#
# - убедиться, что модель Catboost обучается и проверяется на подобных выборках. Желательно убрать масштабирование в числовых признаках.
#
# На данном этапе проект практически завершен, я также отметил рекомендации. У нас еще есть время — я отправлю проект, чтобы ты мог ознакомиться с проверкой, внести изменения и возможно задать вопросы =)
#
# Также на будущее стоит иметь ввиду, что метрика ROC-AUC является не единственной, всегда нужно прислушиваться к требованиями бизнеса. Обычно одной метрикой не ограничиваются, смотрят также Precision, Recall, и выбирают те, которые наиболее подходят для конкретных задач.
#
# Еще нужно смотреть на важность признаков в модели, чтобы понимать, какие параметры влияют на отток.
#
# Проверка важности признаков по модели это только один из способов (корреляция в том числе). Используют также аналитические методы проверки гипотез.
#
# </font>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Даниил, поздравляю с выполнением основной части проекта!
#
# Вижу, что ты уже начал писать отчет.
#
# Необходимо доавить следующие пункты:
#
# - список признаков, которые использовались для обучения;
#
# - отличия от исходного плана работ;
#
# - в отчете нужно указать трудности в работе (если не было, то так и написать) и ключевые этапы (если ключевых этапов не было, то написать, что все этапы важны);
#
# - размер тестовой выборки, параметр random_state.
#
# Я принимаю работу и буду ждать твой отчет на проверку!
#
# </div>

# %% [markdown]
# ## Отчет по проектной деятельности

# %% [markdown]
# Оператор связи «Ниединогоразрыва.ком» поставил задачу прогнозирования оттока клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах. В качестве основной метрики качества заказчик утвердил `ROC-AUC`, которую необходимо довести до значения не менее `0.85`.
#
# Для выполнения поставленной задачи был составлен следующи план работ:
#
# 1. **Провести предобработку данных**, в ходе которого необходимо:
# - Объединенить датасеты в один;
# - Произвести проверку на наличие явных и неявных дубликатов;
# - Обработать пропущенные значения;
# - Привидести данные к требуемому типу данных.
# 2. **Выполнить исследовательский анализ данных**, включающий анализ количественных и категориальных признаков, в том числе, изучение корреляции представленных данных.
#
#
# 3. **Построить и обучить модели машинного обучения**, при этом:
# - Подготовить признаки;
# - Обучить и проанализировать результаты обучения моделей;
# - Произвести проверку наилучшей модели на тестовой выборке.
#
# Все пункты плана были выполнены в полном объеме.

# %% [markdown]
# Основной сложностью проекта являлось определение наиболее важных признаков, влияющих как на продолжительность пользования услугами, так и на факт того, продолжит ли пользователь сотрудничество с оператором связи. Для этого и была произведена предобработка данных с дальнешим исследовательским анализом, на основе которого был выделен целевой признак, определяющий ушел клиент или же нет.

# %% [markdown]
# Предобработка состояла в приведении всех данных в удобный и понятный для анализа вид (удаление пропусков, привидение к требуемому типу данных, проверка на наличие дубликатов). Перед тем как начать предобработку, данные 4 датасетов были объединены в единую таблицу. Далее на этапе исследовательского анализа были сделаны следующие выводы:
#
# 1. Пик ежемесячных тратах приходится на плату около `20` у.е., а значит большинство абнентов пользуется только малой частью услуг;
# 2. Услугами оператора связи воспользовалось огромное количество новых пользователей, в то время, как постоянные пользователи постепенно уменьшаются, кроме наиболее лояльных.
# 3. Текущие и ушедшие пользователи предпочитали ежемесячный тип оплаты. Ушедших пользователй с большим общим платежом гораздо меньше, чем текущих, что может говорить о том, что они редко оплачивали ежегодно или раз в 2 года.
# 4. Пользователи, подключившие Интернет услуги чаще рассторгают сотрудничество с оператором связи, чем пользователи, подключившие телефонные услуги.
# 5. Наиболее популярный тип оплаты - помесячный и безналичный с электронным чеком.
# 6. Наиболее популярный способ подключения - оптоволоконный.
# 7. Все дополнительные услуги не пользуются популярностью у пользователей.

# %% [markdown]
# На основе полученных выводов было принято решение избавиться от нескольких признаков: начала и завершения договора оказания услуг с оператором связи, общих трат на услуги и двух сгенерированных признаков, отвечающих за уточнение, какие основные услуги предоставляются пользователю (телефон и/или Интернет).

# %% [markdown]
# Для предсказаия было выбрано `3` модели машинного обучения `LogisticRegression`, `RandomForrestClassifier` и `CatBoostClassifier`. При обучении были использованы все исходные признаки, кроме удаленных ранее и дополнительный сгенерированный, определяющий длительность пользования услугами оператора связи.
#
# Наилучший результат показала `CatBoostClassifier` при следующих гиперпараметрах: `{'depth': 6, 'iterations': 1000, 'l2_leaf_reg': 1, 'learning_rate': 0.05}`.
#
# Значение `ROC-AUC` составило:
# - на тренировочной выборке `0.913`;
# - на тестовой выборке `0.928`.
#
# Наиболее важными призаками для модели оказались длительность пользования услугами оператора связи и ежемесячные траты на услуги.

# %% [markdown]
# Полученное значение метрики качества `ROC-AUC` соответствует поставленной задаче, а значит выполнение проекта можно считать успешным.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Заключение тимлида:</b> Даниил, было приятно поработать с тобой над финальным проектом! Видно, что ты подошел к проекту основательно, как к реальной работе 👍
#
# На мой взгляд работа выполнена на хорошем уровне! По отчету понятно, какие признаки использовались для обучения, как были получены дополнительные признаки, указана модель для обучения и гиперпараметры — по этим шагам можно воспроизвести проект.
#
# В процессе работы над проектом ты проявил себя как грамотный специалист — могу отметить самостоятельность и аналитический подход! Хочу также отметить подробный анализ данных и раздел с обучением моделей.
#
# ✨ Поздравляю тебя с успешным завершением финального спринта! Если вспомнить, с чего начиналось обучение, видно как от простых задач мы перешли к реальным проектам, и у тебя это здорово получилось 👍
#
# Сейчас ты можешь доработать этот проект с учетом рекомендаций, удалить наши с тобой комментарии и добавить себе в портфолио — лучше это сделать в ближайшее время, пока все нюансы еще отложились в памяти =) Как рекомендация, можно применить Pipeline для подготовки признаков и обучения моделей.
#
# Здесь хочу добавить несколько рекомендаций на будущее:
#
# - для анализа данных по ситуации можно применять библиотеки pandas_profiling или sweetviz. Когда нужен оперативный отчет по датафрейму, можно воспользоваться такими инструментами для автоматизации. Но в учебных проектах мы делали вручную, поскольку должны были всему научиться;
#
# - следует отметить, что можно использовать аналитические методы проверки гипотез для оценки влияния признаков на отток. Например, можно воспользоваться инструментом ANOVA для дисперсионного анализа: https://www.reneshbedre.com/blog/anova.html
#
# ***
#
# Далее, хочу добавить некоторые ссылки на полезные ресурсы по машинному обучению:
#
# https://academy.yandex.ru/handbook/ml онлайн-учебник от Школы анализа данных Яндекса, в котором описаны теоретические основы работы моделей машинного обучения;
#
# https://www.youtube.com/watch?v=xl1fwCza9C8 познавательное видео по настройке модели CatBoost
#
# https://habr.com/ru/company/ods/blog/322626/ на Habr можно закрепить свои знания, порешав задачи из цикла статей — Открытый курс машинного обучения
#
# https://github.com/esokolov/ml-course-hse — на гитхаб есть репозиторий с задачами из курса по машинному обучению от Евгения Соколова, можно использовать как дополнительный материал для закрепления знаний.
#
# https://habr.com/ru/company/avito/blog/571094/ — материалы по A/B тестам.
#
# Также хочу поделиться опытом и вкратце рассказать о том, в какие направления можно подаваться на работу и какие навыки там пригодятся:
#
# Направление аналитики: хорошие знания теории вероятностей и математической статистики; базовые знания библиотек ML; уверенные знания SQL; умение решать задачи по A/B тестам; плюсом будет знание специальных инструментов для аналитики по визуализации результатов.
#
# Направление ML: уверенные знания классических моделей машинного обучения; хорошие знания SQL; понимание алгоритмов машинного обучения — как устроена модель линейной регрессии, модели случайного леса, градиентного бустинга и т.д. На собеседовании могут спросить, как работает какая-нибудь модель «под капотом», очень любят градиентный бустинг и случайный лес. Здесь поможет учебник https://academy.yandex.ru/handbook/ml
#
# В некоторых компаниях при устройстве на работу или стажировку, например в Яндексе, нужно решить тест на алгоритмические задачи. По алгоритмам есть много разных курсов, платных и бесплатных. Можно попробовать Тренировки по Алгоритмам от Яндекса https://yandex.ru/yaintern/algorithm-training (бесплатно, хороший курс). Насколько знаю, у Практикума тоже есть курс по алгоритмам.
#
# Есть компании, где требуется умение решать задачи с использованием нейронных сетей, в основном задачи распознавания изображений и анализа текстов (NLP). Если понравилось работать с нейронками, желательно порешать разные задачи, набрать портфолио из нескольких работ, можно подаваться.
#
# Существуют научные и производственные компании, которые внедряют алгоритмы ML в свои рабочие процессы — в таких компаниях можно совместить должность, например инженера и программиста. Тоже хороший вариант, но нужно понимать, если хотите развиваться дальше, особенно на первых этапах, у вас должны быть опытные наставники, которые помогут советом.
#
# ***
#
# После окончания финального спринта у нас будет заключительная консультация, где мы сможем подвести итоги и обсудить несколько проектов. Есть возможность выступить перед сокурсниками со своим проектом в zoom =)
#
# Отчет принимаю и до встречи!
#
# </div>
